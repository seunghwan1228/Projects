# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
# x = n,m
# y = n,m

x = tf.random.normal(shape=(10, 2))

y = tf.random.normal(shape=(10,2))

# %%
tf.matmul(x, y, transpose_a=True)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[ 4.8385754,  6.1624393],
#        [-1.5577376,  3.5232193]], dtype=float32)>

# %%
tf.matmul(x, y, transpose_b=True)
# Out:
# <tf.Tensor: shape=(10, 10), dtype=float32, numpy=
# array([[ 3.8475115e+00, -1.7197486e+00, -1.6886115e+00,  8.5631800e-01,
#          4.4638610e-01, -1.8264720e+00,  8.4523611e-02, -2.5287600e+00,
#          1.9925997e-01, -1.7597123e+00],
#        [-3.8986676e+00,  1.4323384e+00,  1.3716136e+00, -8.3425933e-01,
#         -2.0747633e-01,  1.3395773e+00, -4.2346012e-02,  2.1305957e+00,
#         -5.5652016e-01,  1.7096623e+00],
#        [ 2.7162251e+00, -9.1456127e-01, -8.6441624e-01,  5.7224852e-01,
#          7.8770965e-02, -7.9596025e-01,  1.7869528e-02, -1.3683970e+00,
#          4.8299932e-01, -1.1714001e+00],
#        [ 1.8333666e+00, -3.6338678e-01, -3.0566639e-01,  3.5888079e-01,
#         -1.4720011e-01, -1.1892610e-01, -2.3374215e-02, -5.7027394e-01,
#          6.1620408e-01, -7.3055315e-01],
#        [-1.4112020e+00, -2.8203121e-01, -3.7927806e-01, -2.1569285e-01,
#          5.5658633e-01, -8.3392805e-01,  9.6387357e-02, -3.4277296e-01,
#         -1.1163210e+00,  4.2935780e-01],
#        [ 7.1863637e+00, -2.9861593e-01,  3.3484966e-02,  1.2853822e+00,
#         -1.4653605e+00,  1.3885503e+00, -2.4873199e-01, -6.6868865e-01,
#          3.7020094e+00, -2.5971079e+00],
#        [-5.3425884e+00,  2.2300754e+00,  2.1719887e+00, -1.1720445e+00,
#         -4.9521184e-01,  2.2760046e+00, -9.5326521e-02,  3.2916026e+00,
#         -4.5719492e-01,  2.4061201e+00],
#        [-8.1741595e-01,  4.3291354e-01,  4.3264946e-01, -1.8920831e-01,
#         -1.4813921e-01,  4.9932423e-01, -2.7384091e-02,  6.3124353e-01,
#          3.4865890e-02,  3.8984594e-01],
#        [-2.3386157e+00,  6.4572465e-01,  5.8922809e-01, -4.7742149e-01,
#          4.3993577e-02,  4.5186454e-01,  4.3892395e-03,  9.8097771e-01,
#         -5.7779366e-01,  9.7501093e-01],
#        [-3.8895352e+00,  1.3384218e+00,  1.2693242e+00, -8.2254368e-01,
#         -1.3552649e-01,  1.1872396e+00, -2.9608259e-02,  1.9995780e+00,
#         -6.5871829e-01,  1.6842203e+00]], dtype=float32)>

# %%
x = np.array([[1,2,3], [11,12,13]])

# %%
x
# Out:
# array([[ 1,  2,  3],
#        [11, 12, 13]])

# %%
x.shape
# Out:
# (2, 3)

# %%
pd.DataFrame(x)
# Out:
#     0   1   2
# 0   1   2   3
# 1  11  12  13

# %%
tf.random.normal(shape=(2,2))
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[0.633568  , 0.54326594],
#        [0.9403363 , 0.6177931 ]], dtype=float32)>

# %%
a = np.array([1,2,3])
b = np.array([10,11,12])

np.dot(a, b)
# Out:
# 68
