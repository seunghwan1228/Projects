# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import time
import os
import unicodedata
import re
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pandas as pd
import sys

# %%
# Set random seed 
np.random.seed(500)
tf.random.set_seed(500)

# %%
class hyperparam:
  embedding_dim = 128
  batch_size=100
  num_epochs = 30

hp = hyperparam()

# %%
file_path = tf.keras.utils.get_file('spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip', extract=True)
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# 2646016/2638744 [==============================] - 0s 0us/step

# %%
file_path
# Out:
# '/root/.keras/datasets/spa-eng.zip'

# %%
os.listdir('/root/.keras/datasets/spa-eng')
# Out:
# ['_about.txt', 'spa.txt']

# %%
text_file = '/root/.keras/datasets/spa-eng/spa.txt'

# %%
df = pd.read_csv(text_file, sep='\t', header=None)
df.columns = ['eng', 'spa']
df.head()
# Out:
#    eng      spa
# 0  Go.      Ve.
# 1  Go.    Vete.
# 2  Go.    Vaya.
# 3  Go.  Váyase.
# 4  Hi.    Hola.

# %%
def unicode_to_ascii(string):
  '''
  NFD = Normal Form Decomposed
  Mn = Nonspacing_Mark
  '''
  return ''.join(char for char in unicodedata.normalize('NFD', string) if unicodedata.category(char) != 'Mn')

# %%
def preprocess_sentence(sentence):
  sentence = unicode_to_ascii(sentence.lower().strip())
  sentence = re.sub(r'([?.!,¿])', r' \1 ', sentence)
  sentence = re.sub(r'[" "]+', ' ', sentence)
  sentence = re.sub(r'[^a-zA-Z?.!,¿]+', ' ' , sentence)
  sentence = sentence.rstrip().strip()
  sentence = '<start>' + sentence + '<end>'
  return sentence

# %%
def create_dataset(path, num_examples):
  lines = open(path, encoding='utf8').read().strip().split('\n')
  word_pair = [[preprocess_sentence(sentence) for sentence in line.split('\t')] for line in lines[:num_examples]]
  return zip(*word_pair)

# %%
english_sentence, spanish_sentence = create_dataset(path=text_file, num_examples=None)

# %%
type(english_sentence)
# Out:
# tuple

# %%
english_sentence[:3]
# Out:
# ('<start>go .<end>', '<start>go .<end>', '<start>go .<end>')

# %%
def max_length(tensor):
  return max(len(tensor_unit) for tensor_unit in tensor)

# %%
def tokenize(language):
  language_token = tf.keras.preprocessing.text.Tokenizer(filters='')
  language_token.fit_on_texts(language)
  tensor = language_token.texts_to_sequences(language)
  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, maxlen = max_length(tensor), padding='post')
  return tensor, language_token

# %%
def load_dataset(path, num_examples=None):
  target_language, input_language = create_dataset(path, num_examples)

  input_tensor, input_language_token = tokenize(input_language)
  target_tensor, target_language_token = tokenize(target_language)

  return input_tensor, input_language_token, target_tensor, target_language_token

# %%
input_tensor, input_language_token, target_tensor, target_language_token = load_dataset(text_file)

# %%
print(input_tensor.shape)
input_tensor
# Out:
# (118964, 51)
# array([[1411,    1,    0, ...,    0,    0,    0],
#        [1770,    1,    0, ...,    0,    0,    0],
#        [3712,    1,    0, ...,    0,    0,    0],
#        ...,
#        [ 410, 6271,    3, ...,    0,    0,    0],
#        [ 856, 1481,  151, ...,    0,    0,    0],
#        [ 119,  129, 1572, ...,   56, 2248,    1]], dtype=int32)

# %%
print(target_tensor.shape)
target_tensor
# Out:
# (118964, 49)
# array([[  637,     1,     0, ...,     0,     0,     0],
#        [  637,     1,     0, ...,     0,     0,     0],
#        [  637,     1,     0, ...,     0,     0,     0],
#        ...,
#        [  180,  4635,  9532, ...,     0,     0,     0],
#        [ 1275,    86,    41, ...,     1,     0,     0],
#        [  170,     5,    36, ..., 14545, 14546,     1]], dtype=int32)

# %%
input_vocabulary_size = len(input_language_token.index_word) + 1
target_vocabulary_size = len(target_language_token.index_word) + 1

# %%
X_train, X_test, y_train, y_test = train_test_split(input_tensor, target_tensor, test_size=0.2, random_state=500)

# %%
print(X_train.shape) # encoder input 
print(y_train.shape) # decoder output 
print('---')
print(X_test.shape) # encoder input
print(y_test.shape) # decoder output
# Out:
# (95171, 51)
# (95171, 49)
# ---
# (23793, 51)
# (23793, 49)

# %%
# create decoder input
print(y_train.shape)
y_train
# Out:
# (95171, 49)
# array([[  20,  409, 1266, ...,    0,    0,    0],
#        [  20,  502,   10, ...,    0,    0,    0],
#        [  39,   54, 5714, ...,    0,    0,    0],
#        ...,
#        [   2,  133,    3, ...,    0,    0,    0],
#        [  74, 1307,  246, ...,    0,    0,    0],
#        [  15,  294,   96, ...,    0,    0,    0]], dtype=int32)

# %%
y_train_input = np.zeros(shape=y_train.shape, dtype=np.int)
y_train_input[:, :-1] = y_train[:, 1:]

# %%
y_train_input.shape
# Out:
# (95171, 49)

# %%
y_train_input
# Out:
# array([[ 409, 1266,    4, ...,    0,    0,    0],
#        [ 502,   10,  198, ...,    0,    0,    0],
#        [  54, 5714,    1, ...,    0,    0,    0],
#        ...,
#        [ 133,    3,    4, ...,    0,    0,    0],
#        [1307,  246, 1039, ...,    0,    0,    0],
#        [ 294,   96,   44, ...,    0,    0,    0]])

# %%
print(y_test.shape)
y_test
# Out:
# (23793, 49)
# array([[  20, 5738, 2416, ...,    0,    0,    0],
#        [   2,  172, 1097, ...,    0,    0,    0],
#        [  15,   10,   58, ...,    0,    0,    0],
#        ...,
#        [   8,  447,    6, ...,    0,    0,    0],
#        [  15, 1449,    3, ...,    0,    0,    0],
#        [2261,   38,  304, ...,    0,    0,    0]], dtype=int32)

# %%
y_test_input = np.zeros(shape=y_test.shape, dtype=np.int)
y_test_input[:, :-1] = y_test[:, 1:]

# %%
y_test_input.shape
# Out:
# (23793, 49)

# %%
y_test_input
# Out:
# array([[5738, 2416, 1638, ...,    0,    0,    0],
#        [ 172, 1097,    1, ...,    0,    0,    0],
#        [  10,   58,  617, ...,    0,    0,    0],
#        ...,
#        [ 447,    6,  603, ...,    0,    0,    0],
#        [1449,    3,  513, ...,    0,    0,    0],
#        [  38,  304, 1030, ...,    0,    0,    0]])

# %%
# x_train, x_test
# y_train, y_test
# y_train_input, y_test_input

train_enc_input, test_enc_input = X_train, X_test
train_dec_output, test_dec_output = y_train, y_test
train_dec_input, test_dec_input = y_train_input, y_test_input

input_vocabulary_size = len(input_language_token.index_word) + 1
target_vocabulary_size = len(target_language_token.index_word) + 1

# %%
class Attention(tf.keras.layers.Layer):
  def __init__(self):
    super(Attention, self).__init__()
  
  def build(self, input_shape):
    # the attention layer gets [encoder_sequence, decoder_hidden_state, target_sequence_length]
    # the hidden state shape = (B, units)
    self.input_sequence_length = input_shape[0][1]
    self.hidden_dim = input_shape[0][2]
    self.target_sequence_length = input_shape[1][1]

    # score function is concat
    self.W_a = tf.keras.layers.Dense(units=self.hidden_dim, use_bias=False)
    self.W_a.build(input_shape=(None, None, self.hidden_dim))
    self._trainable_weights += self.W_a._trainable_weights

    self.U_a = tf.keras.layers.Dense(units=self.hidden_dim, use_bias=False)
    self.U_a.build(input_shape = (None, None, self.hidden_dim))
    self._trainable_weights += self.U_a._trainable_weights
    
    self.V_a = tf.keras.layers.Dense(1, use_bias=False)
    self.V_a.build(input_shape = (None, None, self.hidden_dim))
    self._trainable_weights += self.V_a._trainable_weights
    super(Attention, self).build(input_shape)
  
  def call(self, inputs):
    source_hidden_states = inputs[0]
    target_hidden_state = inputs[1]
    current_timestep = inputs[2]

    target_hidden_state = tf.expand_dims(target_hidden_state, 1)

    weighted_hidden_state = self.W_a(source_hidden_states)
    weighted_target_state = self.U_a(target_hidden_state)

    weighted_sum = weighted_hidden_state + weighted_target_state
    weighted_sum = tf.keras.layers.Activation('tanh')(weighted_sum)

    attention_score = self.V_a(weighted_sum)
    attention_weight = tf.keras.layers.Activation('softmax')(attention_score)
    
    context_vector = source_hidden_states * attention_weight
    return context_vector, attention_weight

# %%
input_sequence_length, target_sequence_length = train_enc_input.shape[-1], train_dec_input.shape[-1]

# %%
input_sequence_length
# Out:
# 51

# %%
# Encoder 
X_input = tf.keras.layers.Input(shape = (input_sequence_length,), name='input_sequences')
emb_input = tf.keras.layers.Embedding(input_vocabulary_size, hp.embedding_dim)(X_input)
encoder_output = tf.compat.v1.keras.layers.CuDNNLSTM(128, return_sequences=True)(emb_input)
encoder_output
# Out:
# <tf.Tensor 'cu_dnnlstm_10/Identity:0' shape=(None, 51, 128) dtype=float32>

# %%
# Decoder
Y_input = tf.keras.layers.Input(shape = (target_sequence_length,), name='target_sequences')
emb_target = tf.keras.layers.Embedding(target_vocabulary_size, hp.embedding_dim)(Y_input)

# To get initial states
initial_hidden_state = tf.keras.layers.Input(shape=(128,), name='hidden_state')
initial_cell_state = tf.keras.layers.Input(shape=(128,), name='cell_state')

hidden_state = initial_hidden_state
cell_state = initial_cell_state

decoder_recurrent_layer = tf.compat.v1.keras.layers.CuDNNLSTM(128, return_state=True)


# Attention Apply
attention_layer = Attention()

decoder_output_dense = tf.keras.layers.Dense(target_vocabulary_size, activation='softmax')

outputs = []
for timestep in range(target_sequence_length):
  current_word = tf.keras.layers.Lambda(lambda x: x[:, timestep:timestep+1, :])(emb_target) 
  context_vector, attention_weight = attention_layer([encoder_output, hidden_state, timestep])

  decoder_input = tf.keras.layers.Concatenate(axis=1)([context_vector, current_word])
  output, hidden_state, cell_state = decoder_recurrent_layer(decoder_input, initial_state=[hidden_state, cell_state])
  decoder_outputs = decoder_output_dense(output)
  outputs.append(decoder_outputs)

print('Attention added output', outputs)

outputs = tf.keras.layers.Lambda(lambda x : tf.keras.backend.permute_dimensions(tf.stack(x), pattern=(1,0,2)))(outputs)
outputs
# Out:
# Attention added output [<tf.Tensor 'dense_38/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_1/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_2/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_3/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_4/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_5/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_6/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_7/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_8/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_9/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_10/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_11/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_12/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_13/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_14/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_15/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_16/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_17/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_18/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_19/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_20/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_21/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_22/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_23/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_24/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_25/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_26/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_27/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_28/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_29/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_30/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_31/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_32/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_33/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_34/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_35/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_36/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_37/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_38/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_39/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_40/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_41/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_42/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_43/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_44/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_45/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_46/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_47/Identity:0' shape=(None, 14547) dtype=float32>, <tf.Tensor 'dense_38_48/Identity:0' shape=(None, 14547) dtype=float32>]
# <tf.Tensor 'lambda_302/Identity:0' shape=(None, 49, 14547) dtype=float32>

# %%
model = tf.keras.models.Model(inputs=[X_input, Y_input, initial_hidden_state, initial_cell_state],
                              outputs=outputs)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# print(model.summary())
# NOTE: Summary is omitted due to length, deriving from number of simulated recurrent connections

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# hidden_state (InputLayer)       [(None, 128)]        0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_249 (Ten [(None, 1, 128)]     0           hidden_state[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [(3,)]               0           tf_op_layer_ExpandDims_249[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [(2,)]               0           tf_op_layer_dense_40/Tensordot/Sh
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [(1,)]               0           tf_op_layer_dense_40/Tensordot/Sh
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [()]                 0           tf_op_layer_dense_40/Tensordot/Ga
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [()]                 0           tf_op_layer_dense_40/Tensordot/Ga
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [(None, 1, 128)]     0           tf_op_layer_ExpandDims_249[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [(2,)]               0           tf_op_layer_dense_40/Tensordot/Pr
#                                                                  tf_op_layer_dense_40/Tensordot/Pr
# __________________________________________________________________________________________________
# input_sequences (InputLayer)    [(None, 51)]         0
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [(None, None)]       0           tf_op_layer_dense_40/Tensordot/tr
#                                                                  tf_op_layer_dense_40/Tensordot/st
# __________________________________________________________________________________________________
# embedding_13 (Embedding)        (None, 51, 128)      3512448     input_sequences[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [(None, 128)]        0           tf_op_layer_dense_40/Tensordot/Re
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot/ [(3,)]               0           tf_op_layer_dense_40/Tensordot/Ga
# __________________________________________________________________________________________________
# cu_dnnlstm_10 (CuDNNLSTM)       (None, 51, 128)      132096      embedding_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Tensordot  [(None, 1, 128)]     0           tf_op_layer_dense_40/Tensordot/Ma
#                                                                  tf_op_layer_dense_40/Tensordot/co
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 51, 128)      16384       cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
#                                                                  cu_dnnlstm_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40/Identity ( [(None, 1, 128)]     0           tf_op_layer_dense_40/Tensordot[0]
# __________________________________________________________________________________________________
# tf_op_layer_add_249 (TensorFlow [(None, 51, 128)]    0           dense_39[0][0]
#                                                                  tf_op_layer_dense_40/Identity[0][
# __________________________________________________________________________________________________
# tf_op_layer_activation_498/Tanh [(None, 51, 128)]    0           tf_op_layer_add_249[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_498/Iden [(None, 51, 128)]    0           tf_op_layer_activation_498/Tanh[0
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [(3,)]               0           tf_op_layer_activation_498/Identi
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [(2,)]               0           tf_op_layer_dense_41/Tensordot/Sh
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [(1,)]               0           tf_op_layer_dense_41/Tensordot/Sh
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [()]                 0           tf_op_layer_dense_41/Tensordot/Ga
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [()]                 0           tf_op_layer_dense_41/Tensordot/Ga
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [(None, 51, 128)]    0           tf_op_layer_activation_498/Identi
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [(2,)]               0           tf_op_layer_dense_41/Tensordot/Pr
#                                                                  tf_op_layer_dense_41/Tensordot/Pr
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [(None, None)]       0           tf_op_layer_dense_41/Tensordot/tr
#                                                                  tf_op_layer_dense_41/Tensordot/st
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [(None, 1)]          0           tf_op_layer_dense_41/Tensordot/Re
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot/ [(3,)]               0           tf_op_layer_dense_41/Tensordot/Ga
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Tensordot  [(None, 51, 1)]      0           tf_op_layer_dense_41/Tensordot/Ma
#                                                                  tf_op_layer_dense_41/Tensordot/co
# __________________________________________________________________________________________________
# tf_op_layer_dense_41/Identity ( [(None, 51, 1)]      0           tf_op_layer_dense_41/Tensordot[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_499/Max  [(None, 51, 1)]      0           tf_op_layer_dense_41/Identity[0][
# __________________________________________________________________________________________________
# tf_op_layer_activation_499/sub  [(None, 51, 1)]      0           tf_op_layer_dense_41/Identity[0][
#                                                                  tf_op_layer_activation_499/Max[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_499/Exp  [(None, 51, 1)]      0           tf_op_layer_activation_499/sub[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_499/Sum  [(None, 51, 1)]      0           tf_op_layer_activation_499/Exp[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_499/true [(None, 51, 1)]      0           tf_op_layer_activation_499/Exp[0]
#                                                                  tf_op_layer_activation_499/Sum[0]
# __________________________________________________________________________________________________
# target_sequences (InputLayer)   [(None, 49)]         0
# __________________________________________________________________________________________________
# tf_op_layer_activation_499/Iden [(None, 51, 1)]      0           tf_op_layer_activation_499/truedi
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 49, 128)      1862016     target_sequences[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_249 (TensorFlow [(None, 51, 128)]    0           cu_dnnlstm_10[0][0]
#                                                                  tf_op_layer_activation_499/Identi
# __________________________________________________________________________________________________
# lambda_253 (Lambda)             (None, 1, 128)       0           embedding_14[0][0]
# __________________________________________________________________________________________________
# concatenate_249 (Concatenate)   (None, 52, 128)      0           tf_op_layer_mul_249[0][0]
#                                                                  lambda_253[0][0]
# __________________________________________________________________________________________________
# cell_state (InputLayer)         [(None, 128)]        0
# __________________________________________________________________________________________________
# cu_dnnlstm_11 (CuDNNLSTM)       [(None, 128), (None, 132096      concatenate_249[0][0]
#                                                                  hidden_state[0][0]
#                                                                  cell_state[0][0]
#                                                                  concatenate_250[0][0]
#                                                                  cu_dnnlstm_11[0][1]
#                                                                  cu_dnnlstm_11[0][2]
#                                                                  concatenate_251[0][0]
#                                                                  cu_dnnlstm_11[1][1]
#                                                                  cu_dnnlstm_11[1][2]
#                                                                  concatenate_252[0][0]
#                                                                  cu_dnnlstm_11[2][1]
#                                                                  cu_dnnlstm_11[2][2]
#                                                                  concatenate_253[0][0]
#                                                                  cu_dnnlstm_11[3][1]
#                                                                  cu_dnnlstm_11[3][2]
#                                                                  concatenate_254[0][0]
#                                                                  cu_dnnlstm_11[4][1]
#                                                                  cu_dnnlstm_11[4][2]
#                                                                  concatenate_255[0][0]
#                                                                  cu_dnnlstm_11[5][1]
#                                                                  cu_dnnlstm_11[5][2]
#                                                                  concatenate_256[0][0]
#                                                                  cu_dnnlstm_11[6][1]
#                                                                  cu_dnnlstm_11[6][2]
#                                                                  concatenate_257[0][0]
#                                                                  cu_dnnlstm_11[7][1]
#                                                                  cu_dnnlstm_11[7][2]
#                                                                  concatenate_258[0][0]
#                                                                  cu_dnnlstm_11[8][1]
#                                                                  cu_dnnlstm_11[8][2]
#                                                                  concatenate_259[0][0]
#                                                                  cu_dnnlstm_11[9][1]
#                                                                  cu_dnnlstm_11[9][2]
#                                                                  concatenate_260[0][0]
#                                                                  cu_dnnlstm_11[10][1]
#                                                                  cu_dnnlstm_11[10][2]
#                                                                  concatenate_261[0][0]
#                                                                  cu_dnnlstm_11[11][1]
#                                                                  cu_dnnlstm_11[11][2]
#                                                                  concatenate_262[0][0]
#                                                                  cu_dnnlstm_11[12][1]
#                                                                  cu_dnnlstm_11[12][2]
#                                                                  concatenate_263[0][0]
#                                                                  cu_dnnlstm_11[13][1]
#                                                                  cu_dnnlstm_11[13][2]
#                                                                  concatenate_264[0][0]
#                                                                  cu_dnnlstm_11[14][1]
#                                                                  cu_dnnlstm_11[14][2]
#                                                                  concatenate_265[0][0]
#                                                                  cu_dnnlstm_11[15][1]
#                                                                  cu_dnnlstm_11[15][2]
#                                                                  concatenate_266[0][0]
#                                                                  cu_dnnlstm_11[16][1]
#                                                                  cu_dnnlstm_11[16][2]
#                                                                  concatenate_267[0][0]
#                                                                  cu_dnnlstm_11[17][1]
#                                                                  cu_dnnlstm_11[17][2]
#                                                                  concatenate_268[0][0]
#                                                                  cu_dnnlstm_11[18][1]
#                                                                  cu_dnnlstm_11[18][2]
#                                                                  concatenate_269[0][0]
#                                                                  cu_dnnlstm_11[19][1]
#                                                                  cu_dnnlstm_11[19][2]
#                                                                  concatenate_270[0][0]
#                                                                  cu_dnnlstm_11[20][1]
#                                                                  cu_dnnlstm_11[20][2]
#                                                                  concatenate_271[0][0]
#                                                                  cu_dnnlstm_11[21][1]
#                                                                  cu_dnnlstm_11[21][2]
#                                                                  concatenate_272[0][0]
#                                                                  cu_dnnlstm_11[22][1]
#                                                                  cu_dnnlstm_11[22][2]
#                                                                  concatenate_273[0][0]
#                                                                  cu_dnnlstm_11[23][1]
#                                                                  cu_dnnlstm_11[23][2]
#                                                                  concatenate_274[0][0]
#                                                                  cu_dnnlstm_11[24][1]
#                                                                  cu_dnnlstm_11[24][2]
#                                                                  concatenate_275[0][0]
#                                                                  cu_dnnlstm_11[25][1]
#                                                                  cu_dnnlstm_11[25][2]
#                                                                  concatenate_276[0][0]
#                                                                  cu_dnnlstm_11[26][1]
#                                                                  cu_dnnlstm_11[26][2]
#                                                                  concatenate_277[0][0]
#                                                                  cu_dnnlstm_11[27][1]
#                                                                  cu_dnnlstm_11[27][2]
#                                                                  concatenate_278[0][0]
#                                                                  cu_dnnlstm_11[28][1]
#                                                                  cu_dnnlstm_11[28][2]
#                                                                  concatenate_279[0][0]
#                                                                  cu_dnnlstm_11[29][1]
#                                                                  cu_dnnlstm_11[29][2]
#                                                                  concatenate_280[0][0]
#                                                                  cu_dnnlstm_11[30][1]
#                                                                  cu_dnnlstm_11[30][2]
#                                                                  concatenate_281[0][0]
#                                                                  cu_dnnlstm_11[31][1]
#                                                                  cu_dnnlstm_11[31][2]
#                                                                  concatenate_282[0][0]
#                                                                  cu_dnnlstm_11[32][1]
#                                                                  cu_dnnlstm_11[32][2]
#                                                                  concatenate_283[0][0]
#                                                                  cu_dnnlstm_11[33][1]
#                                                                  cu_dnnlstm_11[33][2]
#                                                                  concatenate_284[0][0]
#                                                                  cu_dnnlstm_11[34][1]
#                                                                  cu_dnnlstm_11[34][2]
#                                                                  concatenate_285[0][0]
#                                                                  cu_dnnlstm_11[35][1]
#                                                                  cu_dnnlstm_11[35][2]
#                                                                  concatenate_286[0][0]
#                                                                  cu_dnnlstm_11[36][1]
#                                                                  cu_dnnlstm_11[36][2]
#                                                                  concatenate_287[0][0]
#                                                                  cu_dnnlstm_11[37][1]
#                                                                  cu_dnnlstm_11[37][2]
#                                                                  concatenate_288[0][0]
#                                                                  cu_dnnlstm_11[38][1]
#                                                                  cu_dnnlstm_11[38][2]
#                                                                  concatenate_289[0][0]
#                                                                  cu_dnnlstm_11[39][1]
#                                                                  cu_dnnlstm_11[39][2]
#                                                                  concatenate_290[0][0]
#                                                                  cu_dnnlstm_11[40][1]
#                                                                  cu_dnnlstm_11[40][2]
#                                                                  concatenate_291[0][0]
#                                                                  cu_dnnlstm_11[41][1]
#                                                                  cu_dnnlstm_11[41][2]
#                                                                  concatenate_292[0][0]
#                                                                  cu_dnnlstm_11[42][1]
#                                                                  cu_dnnlstm_11[42][2]
#                                                                  concatenate_293[0][0]
#                                                                  cu_dnnlstm_11[43][1]
#                                                                  cu_dnnlstm_11[43][2]
#                                                                  concatenate_294[0][0]
#                                                                  cu_dnnlstm_11[44][1]
#                                                                  cu_dnnlstm_11[44][2]
#                                                                  concatenate_295[0][0]
#                                                                  cu_dnnlstm_11[45][1]
#                                                                  cu_dnnlstm_11[45][2]
#                                                                  concatenate_296[0][0]
#                                                                  cu_dnnlstm_11[46][1]
#                                                                  cu_dnnlstm_11[46][2]
#                                                                  concatenate_297[0][0]
#                                                                  cu_dnnlstm_11[47][1]
#                                                                  cu_dnnlstm_11[47][2]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_250 (Ten [(None, 1, 128)]     0           cu_dnnlstm_11[0][1]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(3,)]               0           tf_op_layer_ExpandDims_250[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(2,)]               0           tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(1,)]               0           tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [()]                 0           tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [()]                 0           tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(None, 1, 128)]     0           tf_op_layer_ExpandDims_250[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(2,)]               0           tf_op_layer_dense_40_1/Tensordot/
#                                                                  tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(None, None)]       0           tf_op_layer_dense_40_1/Tensordot/
#                                                                  tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(None, 128)]        0           tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(3,)]               0           tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Tensordo [(None, 1, 128)]     0           tf_op_layer_dense_40_1/Tensordot/
#                                                                  tf_op_layer_dense_40_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_1/Identity [(None, 1, 128)]     0           tf_op_layer_dense_40_1/Tensordot[
# __________________________________________________________________________________________________
# tf_op_layer_add_250 (TensorFlow [(None, 51, 128)]    0           dense_39[1][0]
#                                                                  tf_op_layer_dense_40_1/Identity[0
# __________________________________________________________________________________________________
# tf_op_layer_activation_500/Tanh [(None, 51, 128)]    0           tf_op_layer_add_250[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_500/Iden [(None, 51, 128)]    0           tf_op_layer_activation_500/Tanh[0
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(3,)]               0           tf_op_layer_activation_500/Identi
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(2,)]               0           tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(1,)]               0           tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [()]                 0           tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [()]                 0           tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(None, 51, 128)]    0           tf_op_layer_activation_500/Identi
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(2,)]               0           tf_op_layer_dense_41_1/Tensordot/
#                                                                  tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(None, None)]       0           tf_op_layer_dense_41_1/Tensordot/
#                                                                  tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(None, 1)]          0           tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(3,)]               0           tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Tensordo [(None, 51, 1)]      0           tf_op_layer_dense_41_1/Tensordot/
#                                                                  tf_op_layer_dense_41_1/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_1/Identity [(None, 51, 1)]      0           tf_op_layer_dense_41_1/Tensordot[
# __________________________________________________________________________________________________
# tf_op_layer_activation_501/Max  [(None, 51, 1)]      0           tf_op_layer_dense_41_1/Identity[0
# __________________________________________________________________________________________________
# tf_op_layer_activation_501/sub  [(None, 51, 1)]      0           tf_op_layer_dense_41_1/Identity[0
#                                                                  tf_op_layer_activation_501/Max[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_501/Exp  [(None, 51, 1)]      0           tf_op_layer_activation_501/sub[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_501/Sum  [(None, 51, 1)]      0           tf_op_layer_activation_501/Exp[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_501/true [(None, 51, 1)]      0           tf_op_layer_activation_501/Exp[0]
#                                                                  tf_op_layer_activation_501/Sum[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_501/Iden [(None, 51, 1)]      0           tf_op_layer_activation_501/truedi
# __________________________________________________________________________________________________
# tf_op_layer_mul_250 (TensorFlow [(None, 51, 128)]    0           cu_dnnlstm_10[0][0]
#                                                                  tf_op_layer_activation_501/Identi
# __________________________________________________________________________________________________
# lambda_254 (Lambda)             (None, 1, 128)       0           embedding_14[0][0]
# __________________________________________________________________________________________________
# concatenate_250 (Concatenate)   (None, 52, 128)      0           tf_op_layer_mul_250[0][0]
#                                                                  lambda_254[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_251 (Ten [(None, 1, 128)]     0           cu_dnnlstm_11[1][1]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(3,)]               0           tf_op_layer_ExpandDims_251[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(2,)]               0           tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(1,)]               0           tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [()]                 0           tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [()]                 0           tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(None, 1, 128)]     0           tf_op_layer_ExpandDims_251[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(2,)]               0           tf_op_layer_dense_40_2/Tensordot/
#                                                                  tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(None, None)]       0           tf_op_layer_dense_40_2/Tensordot/
#                                                                  tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(None, 128)]        0           tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(3,)]               0           tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Tensordo [(None, 1, 128)]     0           tf_op_layer_dense_40_2/Tensordot/
#                                                                  tf_op_layer_dense_40_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_2/Identity [(None, 1, 128)]     0           tf_op_layer_dense_40_2/Tensordot[
# __________________________________________________________________________________________________
# tf_op_layer_add_251 (TensorFlow [(None, 51, 128)]    0           dense_39[2][0]
#                                                                  tf_op_layer_dense_40_2/Identity[0
# __________________________________________________________________________________________________
# tf_op_layer_activation_502/Tanh [(None, 51, 128)]    0           tf_op_layer_add_251[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_502/Iden [(None, 51, 128)]    0           tf_op_layer_activation_502/Tanh[0
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(3,)]               0           tf_op_layer_activation_502/Identi
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(2,)]               0           tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(1,)]               0           tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [()]                 0           tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [()]                 0           tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(None, 51, 128)]    0           tf_op_layer_activation_502/Identi
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(2,)]               0           tf_op_layer_dense_41_2/Tensordot/
#                                                                  tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(None, None)]       0           tf_op_layer_dense_41_2/Tensordot/
#                                                                  tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(None, 1)]          0           tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(3,)]               0           tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Tensordo [(None, 51, 1)]      0           tf_op_layer_dense_41_2/Tensordot/
#                                                                  tf_op_layer_dense_41_2/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_2/Identity [(None, 51, 1)]      0           tf_op_layer_dense_41_2/Tensordot[
# __________________________________________________________________________________________________
# tf_op_layer_activation_503/Max  [(None, 51, 1)]      0           tf_op_layer_dense_41_2/Identity[0
# __________________________________________________________________________________________________
# tf_op_layer_activation_503/sub  [(None, 51, 1)]      0           tf_op_layer_dense_41_2/Identity[0
#                                                                  tf_op_layer_activation_503/Max[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_503/Exp  [(None, 51, 1)]      0           tf_op_layer_activation_503/sub[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_503/Sum  [(None, 51, 1)]      0           tf_op_layer_activation_503/Exp[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_503/true [(None, 51, 1)]      0           tf_op_layer_activation_503/Exp[0]
#                                                                  tf_op_layer_activation_503/Sum[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_503/Iden [(None, 51, 1)]      0           tf_op_layer_activation_503/truedi
# __________________________________________________________________________________________________
# tf_op_layer_mul_251 (TensorFlow [(None, 51, 128)]    0           cu_dnnlstm_10[0][0]
#                                                                  tf_op_layer_activation_503/Identi
# __________________________________________________________________________________________________
# lambda_255 (Lambda)             (None, 1, 128)       0           embedding_14[0][0]
# __________________________________________________________________________________________________
# concatenate_251 (Concatenate)   (None, 52, 128)      0           tf_op_layer_mul_251[0][0]
#                                                                  lambda_255[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_252 (Ten [(None, 1, 128)]     0           cu_dnnlstm_11[2][1]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_3/Tensordo [(3,)]               0           tf_op_layer_ExpandDims_252[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_3/Tensordo [(2,)]               0           tf_op_layer_dense_40_3/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_3/Tensordo [(1,)]               0           tf_op_layer_dense_40_3/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_3/Tensordo [()]                 0           tf_op_layer_dense_40_3/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_3/Tensordo [()]                 0           tf_op_layer_dense_40_3/Tensordot/
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_3/Tensordo [(None, 1, 128)]     0           tf_op_layer_ExpandDims_252[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# tf_op_layer_dense_40_48/Identit [(None, 1, 128)]     0           tf_op_layer_dense_40_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_add_297 (TensorFlow [(None, 51, 128)]    0           dense_39[48][0]
#                                                                  tf_op_layer_dense_40_48/Identity[
# __________________________________________________________________________________________________
# tf_op_layer_activation_594/Tanh [(None, 51, 128)]    0           tf_op_layer_add_297[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_594/Iden [(None, 51, 128)]    0           tf_op_layer_activation_594/Tanh[0
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(3,)]               0           tf_op_layer_activation_594/Identi
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(2,)]               0           tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(1,)]               0           tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [()]                 0           tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [()]                 0           tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(None, 51, 128)]    0           tf_op_layer_activation_594/Identi
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(2,)]               0           tf_op_layer_dense_41_48/Tensordot
#                                                                  tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(None, None)]       0           tf_op_layer_dense_41_48/Tensordot
#                                                                  tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(None, 1)]          0           tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(3,)]               0           tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Tensord [(None, 51, 1)]      0           tf_op_layer_dense_41_48/Tensordot
#                                                                  tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_dense_41_48/Identit [(None, 51, 1)]      0           tf_op_layer_dense_41_48/Tensordot
# __________________________________________________________________________________________________
# tf_op_layer_activation_595/Max  [(None, 51, 1)]      0           tf_op_layer_dense_41_48/Identity[
# __________________________________________________________________________________________________
# tf_op_layer_activation_595/sub  [(None, 51, 1)]      0           tf_op_layer_dense_41_48/Identity[
#                                                                  tf_op_layer_activation_595/Max[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_595/Exp  [(None, 51, 1)]      0           tf_op_layer_activation_595/sub[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_595/Sum  [(None, 51, 1)]      0           tf_op_layer_activation_595/Exp[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_595/true [(None, 51, 1)]      0           tf_op_layer_activation_595/Exp[0]
#                                                                  tf_op_layer_activation_595/Sum[0]
# __________________________________________________________________________________________________
# tf_op_layer_activation_595/Iden [(None, 51, 1)]      0           tf_op_layer_activation_595/truedi
# __________________________________________________________________________________________________
# tf_op_layer_mul_297 (TensorFlow [(None, 51, 128)]    0           cu_dnnlstm_10[0][0]
#                                                                  tf_op_layer_activation_595/Identi
# __________________________________________________________________________________________________
# lambda_301 (Lambda)             (None, 1, 128)       0           embedding_14[0][0]
# __________________________________________________________________________________________________
# concatenate_297 (Concatenate)   (None, 52, 128)      0           tf_op_layer_mul_297[0][0]
#                                                                  lambda_301[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 14547)        1876563     cu_dnnlstm_11[0][0]
#                                                                  cu_dnnlstm_11[1][0]
#                                                                  cu_dnnlstm_11[2][0]
#                                                                  cu_dnnlstm_11[3][0]
#                                                                  cu_dnnlstm_11[4][0]
#                                                                  cu_dnnlstm_11[5][0]
#                                                                  cu_dnnlstm_11[6][0]
#                                                                  cu_dnnlstm_11[7][0]
#                                                                  cu_dnnlstm_11[8][0]
#                                                                  cu_dnnlstm_11[9][0]
#                                                                  cu_dnnlstm_11[10][0]
#                                                                  cu_dnnlstm_11[11][0]
#                                                                  cu_dnnlstm_11[12][0]
#                                                                  cu_dnnlstm_11[13][0]
#                                                                  cu_dnnlstm_11[14][0]
#                                                                  cu_dnnlstm_11[15][0]
#                                                                  cu_dnnlstm_11[16][0]
#                                                                  cu_dnnlstm_11[17][0]
#                                                                  cu_dnnlstm_11[18][0]
#                                                                  cu_dnnlstm_11[19][0]
#                                                                  cu_dnnlstm_11[20][0]
#                                                                  cu_dnnlstm_11[21][0]
#                                                                  cu_dnnlstm_11[22][0]
#                                                                  cu_dnnlstm_11[23][0]
#                                                                  cu_dnnlstm_11[24][0]
#                                                                  cu_dnnlstm_11[25][0]
#                                                                  cu_dnnlstm_11[26][0]
#                                                                  cu_dnnlstm_11[27][0]
#                                                                  cu_dnnlstm_11[28][0]
#                                                                  cu_dnnlstm_11[29][0]
#                                                                  cu_dnnlstm_11[30][0]
#                                                                  cu_dnnlstm_11[31][0]
#                                                                  cu_dnnlstm_11[32][0]
#                                                                  cu_dnnlstm_11[33][0]
#                                                                  cu_dnnlstm_11[34][0]
#                                                                  cu_dnnlstm_11[35][0]
#                                                                  cu_dnnlstm_11[36][0]
#                                                                  cu_dnnlstm_11[37][0]
#                                                                  cu_dnnlstm_11[38][0]
#                                                                  cu_dnnlstm_11[39][0]
#                                                                  cu_dnnlstm_11[40][0]
#                                                                  cu_dnnlstm_11[41][0]
#                                                                  cu_dnnlstm_11[42][0]
#                                                                  cu_dnnlstm_11[43][0]
#                                                                  cu_dnnlstm_11[44][0]
#                                                                  cu_dnnlstm_11[45][0]
#                                                                  cu_dnnlstm_11[46][0]
#                                                                  cu_dnnlstm_11[47][0]
#                                                                  cu_dnnlstm_11[48][0]
# __________________________________________________________________________________________________
# lambda_302 (Lambda)             (None, 49, 14547)    0           dense_38[0][0]
#                                                                  dense_38[1][0]
#                                                                  dense_38[2][0]
#                                                                  dense_38[3][0]
#                                                                  dense_38[4][0]
#                                                                  dense_38[5][0]
#                                                                  dense_38[6][0]
#                                                                  dense_38[7][0]
#                                                                  dense_38[8][0]
#                                                                  dense_38[9][0]
#                                                                  dense_38[10][0]
#                                                                  dense_38[11][0]
#                                                                  dense_38[12][0]
#                                                                  dense_38[13][0]
#                                                                  dense_38[14][0]
#                                                                  dense_38[15][0]
#                                                                  dense_38[16][0]
#                                                                  dense_38[17][0]
#                                                                  dense_38[18][0]
#                                                                  dense_38[19][0]
#                                                                  dense_38[20][0]
#                                                                  dense_38[21][0]
#                                                                  dense_38[22][0]
#                                                                  dense_38[23][0]
#                                                                  dense_38[24][0]
#                                                                  dense_38[25][0]
#                                                                  dense_38[26][0]
#                                                                  dense_38[27][0]
#                                                                  dense_38[28][0]
#                                                                  dense_38[29][0]
#                                                                  dense_38[30][0]
#                                                                  dense_38[31][0]
#                                                                  dense_38[32][0]
#                                                                  dense_38[33][0]
#                                                                  dense_38[34][0]
#                                                                  dense_38[35][0]
#                                                                  dense_38[36][0]
#                                                                  dense_38[37][0]
#                                                                  dense_38[38][0]
#                                                                  dense_38[39][0]
#                                                                  dense_38[40][0]
#                                                                  dense_38[41][0]
#                                                                  dense_38[42][0]
#                                                                  dense_38[43][0]
#                                                                  dense_38[44][0]
#                                                                  dense_38[45][0]
#                                                                  dense_38[46][0]
#                                                                  dense_38[47][0]
#                                                                  dense_38[48][0]
# ==================================================================================================
# Total params: 7,531,603
# Trainable params: 7,531,603
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, dpi=200)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Create placeholder variables of 0s
placeholder = tf.zeros(shape=(len(train_enc_input), 128))

# Train multi-step, multi-class classification model
model.fit(x={'input_sequences': train_enc_input, 'target_sequences': train_dec_input,
             'hidden_state': placeholder, 'cell_state': placeholder},
          y= train_dec_output,
          epochs=hp.num_epochs, batch_size=hp.batch_size)
# Out:
# Train on 95171 samples
# Epoch 1/30
# 95171/95171 [==============================] - 629s 7ms/sample - loss: 1.5805 - accuracy: 0.8425
# Epoch 2/30
# 95171/95171 [==============================] - 586s 6ms/sample - loss: 1.3876 - accuracy: 0.8434
# Epoch 3/30
# 95171/95171 [==============================] - 587s 6ms/sample - loss: 1.3873 - accuracy: 0.8434
# Epoch 4/30
# 95171/95171 [==============================] - 586s 6ms/sample - loss: 1.3858 - accuracy: 0.8434
# Epoch 5/30
# 95171/95171 [==============================] - 587s 6ms/sample - loss: 1.3848 - accuracy: 0.8434
# Epoch 6/30
# 95171/95171 [==============================] - 588s 6ms/sample - loss: 1.3840 - accuracy: 0.8434
# Epoch 7/30
# 47300/95171 [=============>................] - ETA: 4:56 - loss: 1.3826 - accuracy: 0.8436
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-200-2803520ba5a6> in <module>()
#       5              'hidden_state': placeholder, 'cell_state': placeholder},
#       6           y= train_dec_output,
# ----> 7           epochs=hp.num_epochs, batch_size=hp.batch_size)
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
def evaluate(sentence):
  attention_plot = np.zeros((target_sequence_length, input_sequence_length))

  sentence = preprocess_sentence(sentence)

  inputs = [input_language_token[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=input_sequence_length, padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, 128))]
  enc_out, = encoder_output(inputs)

  for t in range(target_sequence_length):
    prediction, dec_hidden, attention_weight =

# %%
test_dec_output.shape
# Out:
# (23793, 49)

# %%
# Test env

input_ =tf.keras.layers.Input(shape=(52,))
emb = tf.keras.layers.Embedding(100, 128)(input_)
gru = tf.keras.layers.GRU(100, return_sequences=True, return_state=True)(emb)

# %%
gru
# Out:
# [<tf.Tensor 'gru/Identity:0' shape=(None, 52, 100) dtype=float32>,
#  <tf.Tensor 'gru/Identity_1:0' shape=(None, 100) dtype=float32>]

# %%
tf.rank(emb).numpy()
tf.rank(gru[0])
# Out:
# 3
