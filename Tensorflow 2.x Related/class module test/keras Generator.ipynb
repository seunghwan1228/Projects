# %%
# %tensorflow_version 2.x
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# TensorFlow 2.x selected.

# %%
class my_gen(tf.keras.utils.Sequence):
  def __init__(self, x, y, batch):
    self.x = x
    self.y = y
    self.batch = batch

  def __len__(self):
    return np.ceil(len(self.x) / len(self.batch))

  def __getitem__(self, idx):
    batch_x = self.x[idx * self.batch : (idx+1)*self.batch]
    batch_y = self.y[idx * self.batch : (idx+1)*self.batch]

    return np.array([resize(imread(file_name), (200,200)) for file_name in batch_x]), np.array(batch_y)
