# %%
import tensorflow as tf
import numpy as np
import unicodedata 
import re

# %%
raw_data = (
    ('What a ridiculous concept!', 'Quel concept ridicule !'),
    ('Your idea is not entirely crazy.', "Votre idée n'est pas complètement folle."),
    ("A man's worth lies in what he is.", "La valeur d'un homme réside dans ce qu'il est."),
    ('What he did is very wrong.', "Ce qu'il a fait est très mal."),
    ("All three of you need to do that.", "Vous avez besoin de faire cela, tous les trois."),
    ("Are you giving me another chance?", "Me donnez-vous une autre chance ?"),
    ("Both Tom and Mary work as models.", "Tom et Mary travaillent tous les deux comme mannequins."),
    ("Can I have a few minutes, please?", "Puis-je avoir quelques minutes, je vous prie ?"),
    ("Could you close the door, please?", "Pourriez-vous fermer la porte, s'il vous plaît ?"),
    ("Did you plant pumpkins this year?", "Cette année, avez-vous planté des citrouilles ?"),
    ("Do you ever study in the library?", "Est-ce que vous étudiez à la bibliothèque des fois ?"),
    ("Don't be deceived by appearances.", "Ne vous laissez pas abuser par les apparences."),
    ("Excuse me. Can you speak English?", "Je vous prie de m'excuser ! Savez-vous parler anglais ?"),
    ("Few people know the true meaning.", "Peu de gens savent ce que cela veut réellement dire."),
    ("Germany produced many scientists.", "L'Allemagne a produit beaucoup de scientifiques."),
    ("Guess whose birthday it is today.", "Devine de qui c'est l'anniversaire, aujourd'hui !"),
    ("He acted like he owned the place.", "Il s'est comporté comme s'il possédait l'endroit."),
    ("Honesty will pay in the long run.", "L'honnêteté paye à la longue."),
    ("How do we know this isn't a trap?", "Comment savez-vous qu'il ne s'agit pas d'un piège ?"),
    ("I can't believe you're giving up.", "Je n'arrive pas à croire que vous abandonniez."),
)

# %%
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')


def normalize_string(s):
  s = unicode_to_ascii(s)
  s = re.sub(r'([!.?])', r' \1 ', s)
  s = re.sub(r'[^a-zA-Z.!?]+', r' ', s)
  s = re.sub(r'\s+', r' ', s)
  return s

# %%
raw_data_en, raw_data_fr = list(zip(*raw_data))

# %%
raw_data_en, raw_data_fr = list(raw_data_en), list(raw_data_fr)

# %%
normalize_string(raw_data_en[0])
# Out:
# 'What a ridiculous concept ! '

# %%
raw_data_en = [normalize_string(data) for data in raw_data_en]

raw_data_fr_in = ['<start> ' + normalize_string(data) for data in raw_data_fr]
raw_data_fr_out = [normalize_string(data) + ' <end>' for data in raw_data_fr]

# %%
print('FR Input : ', raw_data_fr_in[0])
print('FR Output:', raw_data_fr_out[0])
# Out:
# FR Input :  <start> Quel concept ridicule !
# FR Output: Quel concept ridicule !  <end>

# %%
en_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')

en_tokenizer.fit_on_texts(raw_data_en)

# %%
data_en = en_tokenizer.texts_to_sequences(raw_data_en)

# %%
data_en = tf.keras.preprocessing.sequence.pad_sequences(data_en, padding='post')

# %%
data_en
# Out:
# array([[ 8,  5, 21, 22, 23,  0,  0,  0,  0,  0],
#        [24, 25,  6, 26, 27, 28,  1,  0,  0,  0],
#        [ 5, 29, 30, 31, 32,  9,  8,  7,  6,  1],
#        [ 8,  7, 13,  6, 33, 34,  1,  0,  0,  0],
#        [35, 36, 37,  2, 38, 39, 10, 40,  1,  0],
#        [41,  2, 14, 15, 42, 43,  3,  0,  0,  0],
#        [44, 45, 46, 47, 48, 49, 50,  1,  0,  0],
#        [11, 16, 51,  5, 17, 52, 18,  3,  0,  0],
#        [53,  2, 54,  4, 55, 18,  3,  0,  0,  0],
#        [13,  2, 56, 57, 19, 58,  3,  0,  0,  0],
#        [10,  2, 59, 60,  9,  4, 61,  3,  0,  0],
#        [62, 12, 63, 64, 65, 66,  1,  0,  0,  0],
#        [67, 15,  1, 11,  2, 68, 69,  3,  0,  0],
#        [17, 70, 20,  4, 71, 72,  1,  0,  0,  0],
#        [73, 74, 75, 76,  1,  0,  0,  0,  0,  0],
#        [77, 78, 79, 80,  6, 81,  1,  0,  0,  0],
#        [ 7, 82, 83,  7, 84,  4, 85,  1,  0,  0],
#        [86, 87, 88,  9,  4, 89, 90,  1,  0,  0],
#        [91, 10, 92, 20, 19, 93, 12,  5, 94,  3],
#        [16, 11, 12, 95,  2, 96, 14, 97,  1,  0]], dtype=int32)

# %%
fr_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')


# FIT twice can append the tokens
fr_tokenizer.fit_on_texts(raw_data_fr_in)
fr_tokenizer.fit_on_texts(raw_data_fr_out)


data_fr_in = fr_tokenizer.texts_to_sequences(raw_data_fr_in)
data_fr_in = tf.keras.preprocessing.sequence.pad_sequences(data_fr_in, padding='post')

data_fr_out = fr_tokenizer.texts_to_sequences(raw_data_fr_out)
data_fr_out = tf.keras.preprocessing.sequence.pad_sequences(data_fr_out, padding='post')

# %%
dataset = tf.data.Dataset.from_tensor_slices((data_en, data_fr_in, data_fr_out)).shuffle(20).batch(5)

# %% [markdown]
# ## Seq2Seq without Attention

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_size, lstm_size):
    super(Encoder, self).__init__()
    self.lstm_size = lstm_size
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
    self.lstm = tf.keras.layers.LSTM(lstm_size, return_sequences=True, return_state=True)

  def call(self, sequence, states):
    embed = self.embedding(sequence)
    output, state_h, state_c = self.lstm(embed, states)

    return output, state_h, state_c

  def init_states(self, batch_size):
    return (tf.zeros([batch_size, self.lstm_size]), # state h
            tf.zeros([batch_size, self.lstm_size])) # state c

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_size, lstm_size):
    super(Decoder, self).__init__()
    self.lstm_size = lstm_size
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
    self.lstm = tf.keras.layers.LSTM(lstm_size, return_sequences=True, return_state=True)

    self.dense = tf.keras.layers.Dense(vocab_size)

  def call(self, sequence, state):
    embed = self.embedding(sequence)
    lstm_output, state_h, state_c = self.lstm(embed, state)
    logits = self.dense(lstm_output)

    return logits, state_h, state_c

# %%
EMBEDDING_SIZE = 32
LSTM_SIZE = 64

en_vocab_size = len(en_tokenizer.word_index) + 1

encoder = Encoder(en_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)


fr_vocab_size = len(fr_tokenizer.word_index) + 1
decoder = Decoder(fr_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)



source_input = tf.constant([[1,3,5,7,2,0,0,0]])
initial_state = encoder.init_states(1)

encoder_output, en_state_h, en_state_c = encoder(source_input, initial_state)

target_input = tf.constant([[1,4,6,9,2,0,0]])
decoder_output, de_state_h, de_state_c = decoder(target_input, (en_state_h, en_state_c))

# %%
print('Source sequences', source_input.shape)
print('Encoder outputs', encoder_output.shape)
print('Encoder state_h', en_state_h.shape)
print('Encoder state_c', en_state_c.shape)

print('\nDestination vocab size', fr_vocab_size)
print('Destination sequences', target_input.shape)
print('Decoder outputs', decoder_output.shape)
print('Decoder state_h', de_state_h.shape)
print('Decoder state_c', de_state_c.shape)
# Out:
# Source sequences (1, 8)
# Encoder outputs (1, 8, 64)
# Encoder state_h (1, 64)
# Encoder state_c (1, 64)
#
# Destination vocab size 110
# Destination sequences (1, 7)
# Decoder outputs (1, 7, 110)
# Decoder state_h (1, 64)
# Decoder state_c (1, 64)

# %%
def loss_func(targets, logits):
  crossentropy = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

  mask = tf.math.logical_not(tf.math.equal(targets, 0))
  mask = tf.cast(mask, dtype=tf.int64)

  loss = crossentropy(targets, logits, sample_weight=mask)

  return loss

# %%
optimizer = tf.keras.optimizers.Adam()

# %%
@tf.function
def train_step(source_seq, target_seq_in, target_seq_out, en_initial_states):
  with tf.GradientTape() as tape:
    en_outputs = encoder(source_seq, en_initial_states)
    # en_outpus = (), (), () <- output, state_h, state_c
    en_states = en_outputs[1:]
    de_states = en_states

    de_outputs = decoder(target_seq_in, de_states)
    logits = de_outputs[0]
    loss = loss_func(target_seq_out, logits)
  
  variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, variables)
  optimizer.apply_gradients(zip(gradients, variables))

  return loss

# %%
def predict():
  test_source_text = raw_data_en[np.random.choice(len(raw_data_en))]
  print(test_source_text)

  test_source_seq = en_tokenizer.texts_to_sequences([test_source_text])
  print(test_source_seq)

  en_initial_states = encoder.init_states(1)

  en_outputs = encoder(tf.constant(test_source_seq), en_initial_states)

  de_input = tf.constant([[fr_tokenizer.word_index['<start>']]])

  de_state_h, de_state_c = en_outputs[1:]


  out_words = []
  while True:
    de_output, de_state_h ,de_state_c = decoder(de_input, (de_state_h, de_state_c))

    de_input = tf.argmax(de_output, -1)

    out_words.append(fr_tokenizer.index_word[de_input.numpy()[0][0]])

    if out_words[-1] == '<end>' or len(out_words) >= 20:
      break

  print(' '.join(out_words))
  print()

# %%
NUM_EPOCHS = 250
BATCH_SIZE = 5

for e in range(NUM_EPOCHS):
  en_initial_states = encoder.init_states(BATCH_SIZE)

  for batch, (source_seq, target_seq_in, target_seq_out) in enumerate(dataset.take(-1)):
    loss = train_step(source_seq, target_seq_in, target_seq_out, en_initial_states)

  print('Epoch {} Loss {:.4f}'.format(e+1, loss.numpy()))

  try:
    predict()
  except Exception:
    continue
# Out:
# Epoch 1 Loss 0.0212
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 2 Loss 0.0185
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 3 Loss 0.0174
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il <end>
#
# Epoch 4 Loss 0.0206
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 5 Loss 0.0115
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 6 Loss 0.0163
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 7 Loss 0.0188
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 8 Loss 0.0143
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 9 Loss 0.0154
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 10 Loss 0.0124
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 11 Loss 0.0137
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 12 Loss 0.0145
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 13 Loss 0.0130
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 14 Loss 0.0163
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 15 Loss 0.0212
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 16 Loss 0.0146
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 17 Loss 0.0104
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 18 Loss 0.0189
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 19 Loss 0.0116
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 20 Loss 0.0143
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 21 Loss 0.0195
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 22 Loss 0.0185
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 23 Loss 0.0119
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a fait est . <end>
#
# Epoch 24 Loss 0.0142
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a fait est . <end>
#
# Epoch 25 Loss 0.0174
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 26 Loss 0.0108
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 27 Loss 0.0176
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il <end>
#
# Epoch 28 Loss 0.0146
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 29 Loss 0.0123
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 30 Loss 0.0118
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 31 Loss 0.0143
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 32 Loss 0.0154
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 33 Loss 0.0138
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 34 Loss 0.0155
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 35 Loss 0.0163
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a fait est . <end>
#
# Epoch 36 Loss 0.0139
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 37 Loss 0.0130
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 38 Loss 0.0154
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 39 Loss 0.0103
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 40 Loss 0.0118
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 41 Loss 0.0123
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 42 Loss 0.0196
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 43 Loss 0.0160
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 44 Loss 0.0163
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 45 Loss 0.0166
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 46 Loss 0.0133
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 47 Loss 0.0136
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 48 Loss 0.0160
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 49 Loss 0.0121
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 50 Loss 0.0132
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 51 Loss 0.0104
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 52 Loss 0.0140
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 53 Loss 0.0121
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 54 Loss 0.0100
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 55 Loss 0.0118
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il <end>
#
# Epoch 56 Loss 0.0177
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 57 Loss 0.0140
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 58 Loss 0.0153
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 59 Loss 0.0128
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 60 Loss 0.0150
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 61 Loss 0.0179
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 62 Loss 0.0120
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 63 Loss 0.0117
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 64 Loss 0.0134
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a fait est . <end>
#
# Epoch 65 Loss 0.0080
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 66 Loss 0.0148
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 67 Loss 0.0099
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 68 Loss 0.0127
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 69 Loss 0.0127
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 70 Loss 0.0130
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 71 Loss 0.0122
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 72 Loss 0.0095
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 73 Loss 0.0126
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il vous plait ? <end>
#
# Epoch 74 Loss 0.0098
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 75 Loss 0.0142
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 76 Loss 0.0103
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 77 Loss 0.0155
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 78 Loss 0.0134
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 79 Loss 0.0142
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il vous plait ? <end>
#
# Epoch 80 Loss 0.0138
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 81 Loss 0.0104
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il vous plait ? <end>
#
# Epoch 82 Loss 0.0089
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 83 Loss 0.0094
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 84 Loss 0.0116
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 85 Loss 0.0103
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 86 Loss 0.0094
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 87 Loss 0.0129
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 88 Loss 0.0102
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 89 Loss 0.0115
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 90 Loss 0.0093
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 91 Loss 0.0108
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 92 Loss 0.0113
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 93 Loss 0.0131
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 94 Loss 0.0107
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 95 Loss 0.0111
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 96 Loss 0.0146
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 97 Loss 0.0102
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 98 Loss 0.0105
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 99 Loss 0.0119
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 100 Loss 0.0104
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 101 Loss 0.0097
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 102 Loss 0.0119
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 103 Loss 0.0072
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 104 Loss 0.0077
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 105 Loss 0.0102
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 106 Loss 0.0115
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a fait est . <end>
#
# Epoch 107 Loss 0.0100
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 108 Loss 0.0097
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 109 Loss 0.0109
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 110 Loss 0.0064
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 111 Loss 0.0094
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 112 Loss 0.0102
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 113 Loss 0.0087
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 114 Loss 0.0083
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 115 Loss 0.0070
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a fait est . <end>
#
# Epoch 116 Loss 0.0137
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 117 Loss 0.0126
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 118 Loss 0.0097
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 119 Loss 0.0119
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 120 Loss 0.0092
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 121 Loss 0.0093
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 122 Loss 0.0124
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 123 Loss 0.0106
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 124 Loss 0.0077
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 125 Loss 0.0087
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 126 Loss 0.0101
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 127 Loss 0.0093
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 128 Loss 0.0076
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 129 Loss 0.0096
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 130 Loss 0.0082
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 131 Loss 0.0099
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 132 Loss 0.0088
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 133 Loss 0.0064
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 134 Loss 0.0100
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 135 Loss 0.0100
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 136 Loss 0.0095
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 137 Loss 0.0103
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 138 Loss 0.0097
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 139 Loss 0.0053
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il vous plait ? <end>
#
# Epoch 140 Loss 0.0121
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 141 Loss 0.0077
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 142 Loss 0.0085
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 143 Loss 0.0095
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 144 Loss 0.0108
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 145 Loss 0.0093
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 146 Loss 0.0100
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 147 Loss 0.0118
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 148 Loss 0.0092
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 149 Loss 0.0065
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 150 Loss 0.0066
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 151 Loss 0.0085
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 152 Loss 0.0087
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 153 Loss 0.0055
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 154 Loss 0.0090
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 155 Loss 0.0080
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 156 Loss 0.0061
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 157 Loss 0.0095
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 158 Loss 0.0064
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 159 Loss 0.0077
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 160 Loss 0.0095
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 161 Loss 0.0094
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 162 Loss 0.0084
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 163 Loss 0.0089
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 164 Loss 0.0085
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 165 Loss 0.0080
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 166 Loss 0.0099
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 167 Loss 0.0055
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 168 Loss 0.0080
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 169 Loss 0.0093
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 170 Loss 0.0087
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a fait est . <end>
#
# Epoch 171 Loss 0.0067
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 172 Loss 0.0099
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 173 Loss 0.0067
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 174 Loss 0.0062
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 175 Loss 0.0070
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 176 Loss 0.0070
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a fait est . <end>
#
# Epoch 177 Loss 0.0100
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 178 Loss 0.0095
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 179 Loss 0.0066
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 180 Loss 0.0071
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 181 Loss 0.0083
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 182 Loss 0.0053
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 183 Loss 0.0091
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 184 Loss 0.0053
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 185 Loss 0.0079
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 186 Loss 0.0068
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 187 Loss 0.0076
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 188 Loss 0.0064
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 189 Loss 0.0101
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 190 Loss 0.0078
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 191 Loss 0.0066
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 192 Loss 0.0082
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 193 Loss 0.0062
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 194 Loss 0.0082
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 195 Loss 0.0074
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 196 Loss 0.0084
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 197 Loss 0.0076
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 198 Loss 0.0101
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 199 Loss 0.0071
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 200 Loss 0.0079
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 201 Loss 0.0056
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 202 Loss 0.0056
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 203 Loss 0.0078
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 204 Loss 0.0081
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 205 Loss 0.0073
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 206 Loss 0.0073
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 207 Loss 0.0089
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 208 Loss 0.0068
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 209 Loss 0.0078
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il vous plait ? <end>
#
# Epoch 210 Loss 0.0055
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous laissez pas abuser apparences . <end>
#
# Epoch 211 Loss 0.0068
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 212 Loss 0.0070
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l anniversaire aujourd hui ! <end>
#
# Epoch 213 Loss 0.0062
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 214 Loss 0.0073
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 215 Loss 0.0069
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 216 Loss 0.0055
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 217 Loss 0.0085
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 218 Loss 0.0080
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 219 Loss 0.0073
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 220 Loss 0.0064
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 221 Loss 0.0055
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 222 Loss 0.0081
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 223 Loss 0.0062
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 224 Loss 0.0078
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 225 Loss 0.0080
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 226 Loss 0.0090
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 227 Loss 0.0044
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 228 Loss 0.0051
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# quel concept ridicule ! <end>
#
# Epoch 229 Loss 0.0071
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 230 Loss 0.0064
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 231 Loss 0.0058
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 232 Loss 0.0075
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 233 Loss 0.0064
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous plante des citrouilles ? <end>
#
# Epoch 234 Loss 0.0058
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 235 Loss 0.0067
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 236 Loss 0.0052
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 237 Loss 0.0094
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 238 Loss 0.0050
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
#
# Epoch 239 Loss 0.0063
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela veut reellement dire . <end>
#
# Epoch 240 Loss 0.0063
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 241 Loss 0.0062
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 242 Loss 0.0077
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 243 Loss 0.0062
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 244 Loss 0.0050
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une autre chance ? <end>
#
# Epoch 245 Loss 0.0073
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas completement folle . <end>
#
# Epoch 246 Loss 0.0061
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 247 Loss 0.0055
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il vous plait ? <end>
#
# Epoch 248 Loss 0.0071
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
#
# Epoch 249 Loss 0.0053
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la porte s il vous plait ? <end>
#
# Epoch 250 Loss 0.0043
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>

# %% [markdown]
# ## Seq2Seq with Attention

# %%
class LuongAttention(tf.keras.Model):
  def __init__(self, rnn_size):
    super(LuongAttention, self).__init__()
    self.wa = tf.keras.layers.Dense(rnn_size)

  def call(self, decoder_output, encoder_output):
    score = tf.matmul(decoder_output, self.wa(encoder_output), transpose_b=True)

    alignment = tf.nn.softmax(score, axis=2)
    context = tf.matmul(alignment, encoder_output)
    return context, alignment

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_size, rnn_size):
    super(Decoder, self).__init__()
    self.attention = LuongAttention(rnn_size)
    self.rnn_size = rnn_size
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
    self.lstm = tf.keras.layers.LSTM(rnn_size, return_sequences=True, return_state=True)

    self.wc = tf.keras.layers.Dense(rnn_size, activation='tanh')
    self.ws = tf.keras.layers.Dense(vocab_size)
  
  def call(self, sequence, state, encoder_output):
    embed = self.embedding(sequence)
    lstm_out, state_h, state_c = self.lstm(embed, initial_state=state)

    context, alignment = self.attention(lstm_out, encoder_output)
    lstm_out = tf.concat([tf.squeeze(context, 1), tf.squeeze(lstm_out, 1)], 1)
    lstm_out = self.wc(lstm_out)
    logits = self.ws(lstm_out)

    return logits, state_h, state_c, alignment

# %%
decoder = Decoder(fr_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)

# %%
@tf.function
def train_step(source_seq, target_seq_in, target_seq_out, en_initial_states):
  loss = 0

  with tf.GradientTape() as tape:
    en_outputs = encoder(source_seq, en_initial_states)
    en_states = en_outputs[1:]

    de_state_h, de_state_c = en_states

    for i in range(target_seq_out.shape[1]):
      decoder_in = tf.expand_dims(target_seq_in[:, i], 1)
      logits, de_state_h, de_state_c, _ = decoder(decoder_in, (de_state_h, de_state_c), en_outputs[0])

      loss += loss_func(target_seq_out[:, i], logits)
    
    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return loss / target_seq_out.shape[1]

# %%
def predict(test_source_text=None):
    if test_source_text is None:
        test_source_text = raw_data_en[np.random.choice(len(raw_data_en))]
    print(test_source_text)
    test_source_seq = en_tokenizer.texts_to_sequences([test_source_text])
    print(test_source_seq)

    en_initial_states = encoder.init_states(1)
    en_outputs = encoder(tf.constant(test_source_seq), en_initial_states)

    de_input = tf.constant([[fr_tokenizer.word_index['<start>']]])
    de_state_h, de_state_c = en_outputs[1:]
    out_words = []
    alignments = []

    while True:
        de_output, de_state_h, de_state_c, alignment = decoder(
            de_input, (de_state_h, de_state_c), en_outputs[0])
        de_input = tf.expand_dims(tf.argmax(de_output, -1), 0)
        out_words.append(fr_tokenizer.index_word[de_input.numpy()[0][0]])
        
        alignments.append(alignment.numpy())

        if out_words[-1] == '<end>' or len(out_words) >= 20:
            break

    print(' '.join(out_words))
    return np.array(alignments), test_source_text.split(' '), out_words

# %%
NUM_EPOCHS = 250
BATCH_SIZE = 5

for e in range(NUM_EPOCHS):
  en_initial_states = encoder.init_states(BATCH_SIZE)

  for batch, (source_seq, target_seq_in, target_seq_out) in enumerate(dataset.take(-1)):
    loss = train_step(source_seq, target_seq_in, target_seq_out, en_initial_states)

  print('Epoch {} Loss {:.4f}'.format(e+1, loss.numpy()))

  try:
    predict()
  except Exception:
    continue
# Out:
# Epoch 1 Loss 3.8407
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# <end>
# Epoch 2 Loss 3.6584
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# vous vous vous vous <end>
# Epoch 3 Loss 3.0123
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l . <end>
# Epoch 4 Loss 2.5829
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous pas pas pas . <end>
# Epoch 5 Loss 2.7396
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# pas pas pas pas ? <end>
# Epoch 6 Loss 2.9235
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il il il il il il il <end>
# Epoch 7 Loss 2.2152
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est il il il il il il il <end>
# Epoch 8 Loss 2.1821
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# honnetete honnetete paye a . <end>
# Epoch 9 Loss 1.8679
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous vous vous vous vous vous ? ? <end>
# Epoch 10 Loss 1.5899
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# de de de l l hui hui . <end>
# Epoch 11 Loss 1.5527
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je je vous vous vous vous vous ? <end>
# Epoch 12 Loss 1.5618
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# de de de ce cela cela cela hui . <end>
# Epoch 13 Loss 1.5608
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur valeur homme homme homme d est . <end>
# Epoch 14 Loss 1.6134
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# de de de de cela cela cela tous . <end>
# Epoch 15 Loss 1.5274
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je je je je vous prie ? <end>
# Epoch 16 Loss 1.4134
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je je je je vous vous prie ? <end>
# Epoch 17 Loss 1.4269
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l produit beaucoup scientifiques <end>
# Epoch 18 Loss 1.0211
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l produit beaucoup scientifiques . <end>
# Epoch 19 Loss 1.3978
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que que a la bibliotheque des fois ? <end>
# Epoch 20 Loss 1.1833
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce il il il il . <end>
# Epoch 21 Loss 1.0487
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous vous m m excuser m plait ? <end>
# Epoch 22 Loss 0.9506
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a longue . <end>
# Epoch 23 Loss 0.8131
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# vous vous qu il il il s il vous un un ? <end>
# Epoch 24 Loss 0.9745
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez de de cela cela tous les . <end>
# Epoch 25 Loss 0.6419
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me vous autre chance ? <end>
# Epoch 26 Loss 0.8786
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# de de c l l anniversaire hui ! <end>
# Epoch 27 Loss 0.6045
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# Epoch 28 Loss 0.5466
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire hui ! <end>
# Epoch 29 Loss 0.7756
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent les deux mannequins . <end>
# Epoch 30 Loss 0.5344
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des ? <end>
# Epoch 31 Loss 0.7253
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je je je vous prie vous prie ? <end>
# Epoch 32 Loss 0.5725
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 33 Loss 0.6034
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous abuser abuser les apparences . <end>
# Epoch 34 Loss 0.5265
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a longue . <end>
# Epoch 35 Loss 0.5749
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 36 Loss 0.4386
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez de faire cela tous les trois . <end>
# Epoch 37 Loss 0.3590
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous abuser abuser les apparences . <end>
# Epoch 38 Loss 0.3560
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent les deux comme mannequins . <end>
# Epoch 39 Loss 0.3131
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous abuser abuser les apparences . <end>
# Epoch 40 Loss 0.3534
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# vous gens savent ce que cela reellement dire . <end>
# Epoch 41 Loss 0.2906
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 42 Loss 0.3017
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# Epoch 43 Loss 0.3557
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 44 Loss 0.2917
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous abuser abuser par les apparences . <end>
# Epoch 45 Loss 0.2811
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous trois . <end>
# Epoch 46 Loss 0.3603
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent les deux mannequins . <end>
# Epoch 47 Loss 0.2598
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je je je vous prie ? <end>
# Epoch 48 Loss 0.2689
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 49 Loss 0.2501
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee est completement folle . <end>
# Epoch 50 Loss 0.2692
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens ce que cela reellement dire . <end>
# Epoch 51 Loss 0.2482
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous abuser par les apparences . <end>
# Epoch 52 Loss 0.2007
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 53 Loss 0.1500
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a bibliotheque des fois ? <end>
# Epoch 54 Loss 0.1536
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l produit beaucoup de . <end>
# Epoch 55 Loss 0.1281
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens ce que cela reellement dire . <end>
# Epoch 56 Loss 0.1636
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a bibliotheque des fois ? <end>
# Epoch 57 Loss 0.1842
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 58 Loss 0.1702
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 59 Loss 0.1900
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est completement . <end>
# Epoch 60 Loss 0.1422
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent les deux comme mannequins . <end>
# Epoch 61 Loss 0.1112
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte il vous un ? <end>
# Epoch 62 Loss 0.1528
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante que vous abandonniez . <end>
# Epoch 63 Loss 0.1133
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante que vous abandonniez . <end>
# Epoch 64 Loss 0.1218
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent les deux comme mannequins . <end>
# Epoch 65 Loss 0.0948
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante que vous abandonniez . <end>
# Epoch 66 Loss 0.1173
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 67 Loss 0.1216
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# Epoch 68 Loss 0.1146
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est completement . <end>
# Epoch 69 Loss 0.0947
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte il vous un ? <end>
# Epoch 70 Loss 0.0729
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 71 Loss 0.0959
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 72 Loss 0.1093
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante que vous abandonniez . <end>
# Epoch 73 Loss 0.0621
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 74 Loss 0.0797
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte il vous un ? <end>
# Epoch 75 Loss 0.0985
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 76 Loss 0.0764
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 77 Loss 0.0586
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 78 Loss 0.0846
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 79 Loss 0.0768
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 80 Loss 0.0773
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 81 Loss 0.0682
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a longue . <end>
# Epoch 82 Loss 0.0725
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 83 Loss 0.0728
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte il vous un ? <end>
# Epoch 84 Loss 0.0587
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l produit beaucoup de scientifiques . <end>
# Epoch 85 Loss 0.0624
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 86 Loss 0.0660
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# Epoch 87 Loss 0.0577
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 88 Loss 0.0599
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 89 Loss 0.0641
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a bibliotheque des fois ? <end>
# Epoch 90 Loss 0.0512
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 91 Loss 0.0715
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 92 Loss 0.0504
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a bibliotheque des fois ? <end>
# Epoch 93 Loss 0.0579
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 94 Loss 0.0619
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 95 Loss 0.0476
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a longue . <end>
# Epoch 96 Loss 0.0396
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous autre ? <end>
# Epoch 97 Loss 0.0400
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 98 Loss 0.0541
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 99 Loss 0.0377
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l produit beaucoup de scientifiques . <end>
# Epoch 100 Loss 0.0536
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 101 Loss 0.0378
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante que vous abandonniez . <end>
# Epoch 102 Loss 0.0450
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est anniversaire hui ! <end>
# Epoch 103 Loss 0.0393
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 104 Loss 0.0442
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# Epoch 105 Loss 0.0421
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 106 Loss 0.0413
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a longue . <end>
# Epoch 107 Loss 0.0405
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 108 Loss 0.0339
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est anniversaire hui ! <end>
# Epoch 109 Loss 0.0339
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte il vous un ? <end>
# Epoch 110 Loss 0.0249
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 111 Loss 0.0418
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est completement . <end>
# Epoch 112 Loss 0.0287
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 113 Loss 0.0376
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 114 Loss 0.0221
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 115 Loss 0.0425
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent que cela reellement dire . <end>
# Epoch 116 Loss 0.0292
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 117 Loss 0.0306
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous autre ? <end>
# Epoch 118 Loss 0.0336
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a longue . <end>
# Epoch 119 Loss 0.0311
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la . <end>
# Epoch 120 Loss 0.0253
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 121 Loss 0.0292
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 122 Loss 0.0230
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 123 Loss 0.0313
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 124 Loss 0.0285
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte s il vous un ? <end>
# Epoch 125 Loss 0.0306
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 126 Loss 0.0270
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 127 Loss 0.0242
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 128 Loss 0.0323
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 129 Loss 0.0267
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous abuser par les apparences . <end>
# Epoch 130 Loss 0.0260
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte s il vous un ? <end>
# Epoch 131 Loss 0.0326
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 132 Loss 0.0309
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 133 Loss 0.0287
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous autre ? <end>
# Epoch 134 Loss 0.0302
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a bibliotheque des fois ? <end>
# Epoch 135 Loss 0.0242
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 136 Loss 0.0283
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la . <end>
# Epoch 137 Loss 0.0254
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 138 Loss 0.0177
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas . <end>
# Epoch 139 Loss 0.0148
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 140 Loss 0.0280
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte s il vous un ? <end>
# Epoch 141 Loss 0.0229
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 142 Loss 0.0226
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 143 Loss 0.0234
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 144 Loss 0.0195
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 145 Loss 0.0248
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas . <end>
# Epoch 146 Loss 0.0200
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la . <end>
# Epoch 147 Loss 0.0218
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 148 Loss 0.0192
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a bibliotheque des fois ? <end>
# Epoch 149 Loss 0.0197
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 150 Loss 0.0219
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 151 Loss 0.0197
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 152 Loss 0.0175
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est anniversaire hui ! <end>
# Epoch 153 Loss 0.0232
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 154 Loss 0.0194
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante que vous abandonniez . <end>
# Epoch 155 Loss 0.0223
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 156 Loss 0.0212
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 157 Loss 0.0179
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 158 Loss 0.0196
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la . <end>
# Epoch 159 Loss 0.0175
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas . <end>
# Epoch 160 Loss 0.0173
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est anniversaire hui ! <end>
# Epoch 161 Loss 0.0154
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 162 Loss 0.0160
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 163 Loss 0.0211
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 164 Loss 0.0165
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 165 Loss 0.0136
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 166 Loss 0.0158
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# Epoch 167 Loss 0.0186
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l produit beaucoup de scientifiques . <end>
# Epoch 168 Loss 0.0156
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a bibliotheque des fois ? <end>
# Epoch 169 Loss 0.0150
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la . <end>
# Epoch 170 Loss 0.0145
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela reellement . <end>
# Epoch 171 Loss 0.0183
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte s il vous un ? <end>
# Epoch 172 Loss 0.0162
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des citrouilles ? <end>
# Epoch 173 Loss 0.0189
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 174 Loss 0.0169
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 175 Loss 0.0145
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela reellement . <end>
# Epoch 176 Loss 0.0118
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte s il vous un ? <end>
# Epoch 177 Loss 0.0179
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la . <end>
# Epoch 178 Loss 0.0176
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 179 Loss 0.0197
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 180 Loss 0.0160
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 181 Loss 0.0180
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 182 Loss 0.0150
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela reellement . <end>
# Epoch 183 Loss 0.0140
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 184 Loss 0.0125
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 185 Loss 0.0162
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la fois ? <end>
# Epoch 186 Loss 0.0145
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous abuser par les apparences . <end>
# Epoch 187 Loss 0.0145
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la . <end>
# Epoch 188 Loss 0.0135
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 189 Loss 0.0149
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas . <end>
# Epoch 190 Loss 0.0108
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 191 Loss 0.0117
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 192 Loss 0.0133
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas . <end>
# Epoch 193 Loss 0.0124
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 194 Loss 0.0134
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la fois ? <end>
# Epoch 195 Loss 0.0171
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l produit beaucoup de scientifiques . <end>
# Epoch 196 Loss 0.0083
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte s il vous un ? <end>
# Epoch 197 Loss 0.0123
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous la porte s il vous un ? <end>
# Epoch 198 Loss 0.0126
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous autre ? <end>
# Epoch 199 Loss 0.0125
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas . <end>
# Epoch 200 Loss 0.0140
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 201 Loss 0.0116
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 202 Loss 0.0109
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 203 Loss 0.0145
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la fois ? <end>
# Epoch 204 Loss 0.0131
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela reellement . <end>
# Epoch 205 Loss 0.0160
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 206 Loss 0.0103
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 207 Loss 0.0125
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 208 Loss 0.0124
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 209 Loss 0.0103
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous autre ? <end>
# Epoch 210 Loss 0.0089
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 211 Loss 0.0097
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce que cela reellement . <end>
# Epoch 212 Loss 0.0104
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 213 Loss 0.0139
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 214 Loss 0.0074
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 215 Loss 0.0084
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 216 Loss 0.0098
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque ? <end>
# Epoch 217 Loss 0.0117
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 218 Loss 0.0084
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous abuser par les apparences . <end>
# Epoch 219 Loss 0.0097
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque ? <end>
# Epoch 220 Loss 0.0115
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# mary travaillent tous les deux comme . <end>
# Epoch 221 Loss 0.0095
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 222 Loss 0.0100
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Epoch 223 Loss 0.0115
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 224 Loss 0.0106
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# Epoch 225 Loss 0.0098
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 226 Loss 0.0111
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 227 Loss 0.0108
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l produit beaucoup de scientifiques . <end>
# Epoch 228 Loss 0.0078
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous autre ? <end>
# Epoch 229 Loss 0.0079
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 230 Loss 0.0110
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 231 Loss 0.0076
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 232 Loss 0.0082
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 233 Loss 0.0096
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 234 Loss 0.0086
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 235 Loss 0.0061
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# Epoch 236 Loss 0.0085
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 237 Loss 0.0100
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque ? <end>
# Epoch 238 Loss 0.0108
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 239 Loss 0.0081
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas . <end>
# Epoch 240 Loss 0.0074
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est anniversaire hui ! <end>
# Epoch 241 Loss 0.0095
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee n est pas . <end>
# Epoch 242 Loss 0.0083
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 243 Loss 0.0115
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 244 Loss 0.0082
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 245 Loss 0.0094
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il a tres mal . <end>
# Epoch 246 Loss 0.0105
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 247 Loss 0.0102
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque ? <end>
# Epoch 248 Loss 0.0075
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 249 Loss 0.0094
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque ? <end>
# Epoch 250 Loss 0.0095
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la . <end>
