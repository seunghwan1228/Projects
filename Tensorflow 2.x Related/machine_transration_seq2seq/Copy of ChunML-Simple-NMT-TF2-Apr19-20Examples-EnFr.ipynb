# %% [markdown]
# https://github.com/ChunML/NLP/blob/master/machine_translation/train_simple_tf2.py

# %% [markdown]
# https://machinetalk.org/2019/03/29/neural-machine-translation-with-attention-mechanism/

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import numpy as np
import unicodedata
import re
# Out:
# TensorFlow 2.x selected.

# %%
tf.__version__
# Out:
# '2.1.0'

# %%
raw_data = (
    ('What a ridiculous concept!', 'Quel concept ridicule !'),
    ('Your idea is not entirely crazy.', "Votre idée n'est pas complètement folle."),
    ("A man's worth lies in what he is.", "La valeur d'un homme réside dans ce qu'il est."),
    ('What he did is very wrong.', "Ce qu'il a fait est très mal."),
    ("All three of you need to do that.", "Vous avez besoin de faire cela, tous les trois."),
    ("Are you giving me another chance?", "Me donnez-vous une autre chance ?"),
    ("Both Tom and Mary work as models.", "Tom et Mary travaillent tous les deux comme mannequins."),
    ("Can I have a few minutes, please?", "Puis-je avoir quelques minutes, je vous prie ?"),
    ("Could you close the door, please?", "Pourriez-vous fermer la porte, s'il vous plaît ?"),
    ("Did you plant pumpkins this year?", "Cette année, avez-vous planté des citrouilles ?"),
    ("Do you ever study in the library?", "Est-ce que vous étudiez à la bibliothèque des fois ?"),
    ("Don't be deceived by appearances.", "Ne vous laissez pas abuser par les apparences."),
    ("Excuse me. Can you speak English?", "Je vous prie de m'excuser ! Savez-vous parler anglais ?"),
    ("Few people know the true meaning.", "Peu de gens savent ce que cela veut réellement dire."),
    ("Germany produced many scientists.", "L'Allemagne a produit beaucoup de scientifiques."),
    ("Guess whose birthday it is today.", "Devine de qui c'est l'anniversaire, aujourd'hui !"),
    ("He acted like he owned the place.", "Il s'est comporté comme s'il possédait l'endroit."),
    ("Honesty will pay in the long run.", "L'honnêteté paye à la longue."),
    ("How do we know this isn't a trap?", "Comment savez-vous qu'il ne s'agit pas d'un piège ?"),
    ("I can't believe you're giving up.", "Je n'arrive pas à croire que vous abandonniez."),
)

# %%
def unicode_to_ascii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')


def normalize_string(s):
    s = unicode_to_ascii(s)
    s = re.sub(r'([!.?])', r' \1', s)
    s = re.sub(r'[^a-zA-Z.!?]+', r' ', s)
    s = re.sub(r'\s+', r' ', s)
    return s


raw_data_en, raw_data_fr = list(zip(*raw_data))
raw_data_en, raw_data_fr = list(raw_data_en), list(raw_data_fr)
raw_data_en = [normalize_string(data) for data in raw_data_en]
raw_data_fr_in = ['<start> ' + normalize_string(data) for data in raw_data_fr]
raw_data_fr_out = [normalize_string(data) + ' <end>' for data in raw_data_fr]

en_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
en_tokenizer.fit_on_texts(raw_data_en)
data_en = en_tokenizer.texts_to_sequences(raw_data_en)
data_en = tf.keras.preprocessing.sequence.pad_sequences(data_en,
                                                        padding='post')

fr_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
fr_tokenizer.fit_on_texts(raw_data_fr_in)
fr_tokenizer.fit_on_texts(raw_data_fr_out)
data_fr_in = fr_tokenizer.texts_to_sequences(raw_data_fr_in)
data_fr_in = tf.keras.preprocessing.sequence.pad_sequences(data_fr_in,
                                                           padding='post')

data_fr_out = fr_tokenizer.texts_to_sequences(raw_data_fr_out)
data_fr_out = tf.keras.preprocessing.sequence.pad_sequences(data_fr_out,
                                                            padding='post')

BATCH_SIZE = 5
dataset = tf.data.Dataset.from_tensor_slices(
    (data_en, data_fr_in, data_fr_out))
dataset = dataset.shuffle(20).batch(BATCH_SIZE)

# %%
for n, (en, fr, fr_out) in enumerate(dataset):
  print(n)
  print(en)
  print(fr)
  print(fr_out)
  if n == 0:
    break
# Out:
# 0
# tf.Tensor(
# [[ 5 29 30 31 32  9  8  7  6  1]
#  [35 36 37  2 38 39 10 40  1  0]
#  [13  2 56 57 19 58  3  0  0  0]
#  [17 70 20  4 71 72  1  0  0  0]
#  [53  2 54  4 55 18  3  0  0  0]], shape=(5, 10), dtype=int32)
# tf.Tensor(
# [[ 3 11 38 21 22 39 40 41 12 17  7  6  2  0]
#  [ 3  1 23 45  9 46 24 25 18 47  2  0  0  0]
#  [ 3 67 68 23  1 69 28 70  5  0  0  0  0  0]
#  [ 3 82  9 83 84 12 19 24 85 86 87  2  0  0]
#  [ 3 63  1 64 11 65 14  7  1 66  5  0  0  0]], shape=(5, 14), dtype=int32)
# tf.Tensor(
# [[11 38 21 22 39 40 41 12 17  7  6  2  4  0]
#  [ 1 23 45  9 46 24 25 18 47  2  4  0  0  0]
#  [67 68 23  1 69 28 70  5  4  0  0  0  0  0]
#  [82  9 83 84 12 19 24 85 86 87  2  4  0  0]
#  [63  1 64 11 65 14  7  1 66  5  4  0  0  0]], shape=(5, 14), dtype=int32)

# %%
raw_data_en[0], raw_data_fr[0]
# Out:
# ('What a ridiculous concept !', 'Quel concept ridicule !')

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, lstm_size):
        super(Encoder, self).__init__()
        self.lstm_size = lstm_size
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.lstm = tf.keras.layers.LSTM(
            lstm_size, return_sequences=True, return_state=True)

    def call(self, sequence, states):
        embed = self.embedding(sequence)
        output, state_h, state_c = self.lstm(embed, initial_state=states)

        return output, state_h, state_c

    def init_states(self, batch_size):
        return (tf.zeros([batch_size, self.lstm_size]),
                tf.zeros([batch_size, self.lstm_size]))


class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, lstm_size):
        super(Decoder, self).__init__()
        self.lstm_size = lstm_size
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.lstm = tf.keras.layers.LSTM(
            lstm_size, return_sequences=True, return_state=True)
        self.dense = tf.keras.layers.Dense(vocab_size)

    def call(self, sequence, state):
        embed = self.embedding(sequence)
        lstm_out, state_h, state_c = self.lstm(embed, state)
        logits = self.dense(lstm_out)

        return logits, state_h, state_c

    def init_states(self, batch_size):
        return (tf.zeros([batch_size, self.lstm_size]),
                tf.zeros([batch_size, self.lstm_size]))

# %%
en_vocab_size = len(en_tokenizer.word_index) + 1
fr_vocab_size = len(fr_tokenizer.word_index) + 1

EMBEDDING_SIZE = 32
LSTM_SIZE = 64

encoder = Encoder(en_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)
decoder = Decoder(fr_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)

initial_states = encoder.init_states(1)
encoder_outputs = encoder(tf.constant([[1, 2, 3]]), initial_states)
decoder_outputs = decoder(tf.constant([[1, 2, 3]]), encoder_outputs[1:])

# %%
def loss_func(targets, logits):
    crossentropy = tf.keras.losses.SparseCategoricalCrossentropy(
        from_logits=True)
    mask = tf.math.logical_not(tf.math.equal(targets, 0))
    mask = tf.cast(mask, dtype=tf.int64)
    loss = crossentropy(targets, logits, sample_weight=mask)

    return loss


optimizer = tf.keras.optimizers.Adam()


def predict(test_source_text=None):
    if test_source_text is None:
        r = np.random.choice(len(raw_data_en))
        test_source_text = raw_data_en[r]
        test_target_text = raw_data_fr[r]
    else:
        test_target_text = None
    print('<',test_source_text)
    
    if test_target_text is not None:
      print('=',test_target_text)
      
    test_source_seq = en_tokenizer.texts_to_sequences([test_source_text])
    #print(test_source_seq)

    en_initial_states = encoder.init_states(1)
    en_outputs = encoder(tf.constant(test_source_seq), en_initial_states)

    de_input = tf.constant([[fr_tokenizer.word_index['<start>']]])
    de_state_h, de_state_c = en_outputs[1:]
    out_words = []

    while True:
        de_output, de_state_h, de_state_c = decoder(
            de_input, (de_state_h, de_state_c))
        de_input = tf.argmax(de_output, -1)
        out_words.append(fr_tokenizer.index_word[de_input.numpy()[0][0]])

        if out_words[-1] == '<end>' or len(out_words) >= 20:
            break

    print('>',' '.join(out_words))
    print()


@tf.function
def train_step(source_seq, target_seq_in, target_seq_out, en_initial_states):
    loss = 0
    with tf.GradientTape() as tape:
        en_outputs = encoder(source_seq, en_initial_states)
        en_states = en_outputs[1:]
        de_states = en_states

        de_outputs = decoder(target_seq_in, de_states)
        logits = de_outputs[0]
        loss = loss_func(target_seq_out, logits)

    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return loss

# %%
NUM_EPOCHS = 300

for e in range(NUM_EPOCHS):
    en_initial_states = encoder.init_states(BATCH_SIZE)
    
    predict()

    for batch, (source_seq, target_seq_in, target_seq_out) in enumerate(dataset.take(-1)):
        loss = train_step(source_seq, target_seq_in,
                          target_seq_out, en_initial_states)

    print('Epoch {} Loss {:.4f}'.format(e + 1, loss.numpy()))
# Out:
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > un un de un de prie aujourd aujourd possedait possedait possedait tom tom veut travaillent travaillent d fermer citrouilles citrouilles
#
# Epoch 1 Loss 3.8261
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > un ce ce ce scientifiques scientifiques <end>
#
# Epoch 2 Loss 3.7524
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous vous vous <end>
#
# Epoch 3 Loss 3.1422
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > vous <end>
#
# Epoch 4 Loss 3.5285
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > vous <end>
#
# Epoch 5 Loss 3.6338
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > vous <end>
#
# Epoch 6 Loss 3.4621
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > <end>
#
# Epoch 7 Loss 3.1081
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > <end>
#
# Epoch 8 Loss 3.4274
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > <end>
#
# Epoch 9 Loss 3.0421
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > <end>
#
# Epoch 10 Loss 3.8259
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > vous <end>
#
# Epoch 11 Loss 2.9565
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > vous vous <end>
#
# Epoch 12 Loss 3.3135
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > vous vous vous <end>
#
# Epoch 13 Loss 3.0958
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > vous vous vous vous <end>
#
# Epoch 14 Loss 3.4030
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > vous vous vous vous <end>
#
# Epoch 15 Loss 3.1013
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > vous vous vous vous vous <end>
#
# Epoch 16 Loss 2.6229
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > vous vous vous vous <end>
#
# Epoch 17 Loss 3.0601
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous vous vous <end>
#
# Epoch 18 Loss 2.5240
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > vous vous vous vous vous <end>
#
# Epoch 19 Loss 2.6048
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous vous vous vous <end>
#
# Epoch 20 Loss 3.1712
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > vous vous vous vous <end>
#
# Epoch 21 Loss 2.9543
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > vous vous vous <end>
#
# Epoch 22 Loss 2.5430
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > vous vous vous vous vous <end>
#
# Epoch 23 Loss 2.7327
# < What a ridiculous concept !
# = Quel concept ridicule !
# > vous vous <end>
#
# Epoch 24 Loss 2.8922
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > vous vous vous <end>
#
# Epoch 25 Loss 2.7629
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > vous vous vous vous vous vous vous vous <end>
#
# Epoch 26 Loss 2.4094
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > vous vous vous vous vous vous <end>
#
# Epoch 27 Loss 2.4488
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > vous vous vous vous <end>
#
# Epoch 28 Loss 2.7088
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > vous vous vous vous <end>
#
# Epoch 29 Loss 2.6880
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > vous vous vous vous vous . <end>
#
# Epoch 30 Loss 2.7099
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous vous vous vous . <end>
#
# Epoch 31 Loss 2.9652
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous vous vous vous . <end>
#
# Epoch 32 Loss 2.2816
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > vous vous vous <end>
#
# Epoch 33 Loss 2.6291
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous vous vous vous vous <end>
#
# Epoch 34 Loss 2.4748
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > vous vous vous vous . <end>
#
# Epoch 35 Loss 2.3287
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > vous vous <end>
#
# Epoch 36 Loss 2.3548
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > vous vous vous vous <end>
#
# Epoch 37 Loss 2.7936
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > vous vous <end>
#
# Epoch 38 Loss 2.5061
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > vous vous vous vous vous vous . <end>
#
# Epoch 39 Loss 2.8053
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > vous vous vous <end>
#
# Epoch 40 Loss 2.6319
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > vous vous vous vous vous . <end>
#
# Epoch 41 Loss 2.7006
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > vous vous a pas . <end>
#
# Epoch 42 Loss 2.4889
# < What a ridiculous concept !
# = Quel concept ridicule !
# > l a . <end>
#
# Epoch 43 Loss 2.0524
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > vous vous vous vous . <end>
#
# Epoch 44 Loss 2.3661
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous vous vous vous vous <end>
#
# Epoch 45 Loss 2.4226
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > un un un un qu ce . <end>
#
# Epoch 46 Loss 2.6942
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous vous vous vous ? <end>
#
# Epoch 47 Loss 2.2881
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > vous vous vous pas pas . <end>
#
# Epoch 48 Loss 2.4010
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > vous pas pas pas les . <end>
#
# Epoch 49 Loss 2.2515
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous vous vous vous s s vous ? <end>
#
# Epoch 50 Loss 1.9242
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > vous vous vous s s vous ? <end>
#
# Epoch 51 Loss 2.1009
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > vous pas pas pas les . <end>
#
# Epoch 52 Loss 1.8911
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous vous s pas vous . <end>
#
# Epoch 53 Loss 2.2161
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > vous vous vous vous vous la pas pas les . <end>
#
# Epoch 54 Loss 1.9808
# < What a ridiculous concept !
# = Quel concept ridicule !
# > quel <end>
#
# Epoch 55 Loss 2.1939
# < What a ridiculous concept !
# = Quel concept ridicule !
# > quel <end>
#
# Epoch 56 Loss 2.1746
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > vous vous vous pas pas pas les . <end>
#
# Epoch 57 Loss 1.8271
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > vous vous vous pas pas pas les les . <end>
#
# Epoch 58 Loss 2.2949
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > ce a pas pas . <end>
#
# Epoch 59 Loss 2.2208
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je vous vous vous vous vous ? <end>
#
# Epoch 60 Loss 2.2687
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > vous a a . <end>
#
# Epoch 61 Loss 1.8574
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > les un un un un homme homme qu est . <end>
#
# Epoch 62 Loss 2.0978
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > vous a a a . <end>
#
# Epoch 63 Loss 1.6492
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous vous vous il s s il ? <end>
#
# Epoch 64 Loss 1.7055
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous vous vous la pas les les . <end>
#
# Epoch 65 Loss 1.7450
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > vous vous vous vous s la la pas les les . <end>
#
# Epoch 66 Loss 1.7613
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > ce est est . <end>
#
# Epoch 67 Loss 1.9972
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > je vous vous vous ! <end>
#
# Epoch 68 Loss 1.9821
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > vous vous n pas pas pas les les . <end>
#
# Epoch 69 Loss 1.5544
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a est . <end>
#
# Epoch 70 Loss 1.5211
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous s s s s ? <end>
#
# Epoch 71 Loss 1.4550
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous s la pas les les . <end>
#
# Epoch 72 Loss 1.5310
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > vous a a a . <end>
#
# Epoch 73 Loss 1.6732
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > vous de a a la longue . <end>
#
# Epoch 74 Loss 1.9238
# < What a ridiculous concept !
# = Quel concept ridicule !
# > quel ridicule <end>
#
# Epoch 75 Loss 1.6782
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > vous vous n pas pas pas les les . <end>
#
# Epoch 76 Loss 1.8549
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tous les tous les . <end>
#
# Epoch 77 Loss 1.4478
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a est . <end>
#
# Epoch 78 Loss 1.2392
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je vous de m savent ! vous ? <end>
#
# Epoch 79 Loss 1.3451
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > je de vous vous ! <end>
#
# Epoch 80 Loss 1.2720
# < What a ridiculous concept !
# = Quel concept ridicule !
# > quel ridicule <end>
#
# Epoch 81 Loss 1.5672
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > votre a a a longue . <end>
#
# Epoch 82 Loss 1.5266
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne pas pas les les . <end>
#
# Epoch 83 Loss 1.6837
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > je vous a a la . <end>
#
# Epoch 84 Loss 1.5092
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous vous besoin la faire les les . <end>
#
# Epoch 85 Loss 1.3010
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous la la cela les les ? <end>
#
# Epoch 86 Loss 1.4704
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > l de de anniversaire anniversaire hui ! <end>
#
# Epoch 87 Loss 1.2368
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > votre a a a longue . <end>
#
# Epoch 88 Loss 1.4040
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > mary tous les tous les . <end>
#
# Epoch 89 Loss 1.3701
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous de s s il ? <end>
#
# Epoch 90 Loss 1.5005
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > idee n pas pas folle . <end>
#
# Epoch 91 Loss 1.4041
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous qu il la la agit un ? <end>
#
# Epoch 92 Loss 1.1601
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 93 Loss 1.0645
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 94 Loss 1.0988
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous de s s il ? <end>
#
# Epoch 95 Loss 1.1894
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > je vous a a la des ? <end>
#
# Epoch 96 Loss 1.1151
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > je vous a a la des ? <end>
#
# Epoch 97 Loss 1.3120
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous de m excuser ! vous parler ? <end>
#
# Epoch 98 Loss 0.9843
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > mary tous les tous les . <end>
#
# Epoch 99 Loss 1.2746
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > vous vous qu il il la la la agit un piege ? <end>
#
# Epoch 100 Loss 0.8940
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > je vous a a la des ? <end>
#
# Epoch 101 Loss 1.2824
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous de m excuser ! vous parler ? <end>
#
# Epoch 102 Loss 1.2113
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne pas pas les les . <end>
#
# Epoch 103 Loss 1.0430
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > est est il s il il possedait . <end>
#
# Epoch 104 Loss 0.9423
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous besoin besoin faire cela tous les les . <end>
#
# Epoch 105 Loss 0.9420
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n pas pas pas que vous abandonniez . <end>
#
# Epoch 106 Loss 0.9052
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > ce vous qu il la la agit d un <end>
#
# Epoch 107 Loss 0.8287
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de c est anniversaire aujourd hui <end>
#
# Epoch 108 Loss 1.1636
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > valeur valeur un homme reside dans ce qu est . <end>
#
# Epoch 109 Loss 0.8539
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > valeur valeur valeur un homme reside dans ce qu il est . <end>
#
# Epoch 110 Loss 0.8043
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee vous une autre chance ? <end>
#
# Epoch 111 Loss 0.9186
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous de m excuser ! vous ? <end>
#
# Epoch 112 Loss 0.7195
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne pas pas par les . <end>
#
# Epoch 113 Loss 0.8109
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment vous vous qu il il la la agit d un piege ? <end>
#
# Epoch 114 Loss 1.0060
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > ce vous qu il la la agit d un <end>
#
# Epoch 115 Loss 0.8054
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee vous une autre chance ? <end>
#
# Epoch 116 Loss 0.7007
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 117 Loss 0.8065
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > il il il il il il possedait l . <end>
#
# Epoch 118 Loss 0.6948
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas pas croire que vous . <end>
#
# Epoch 119 Loss 0.6512
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment vous qu il il il la la agit d un piege ? <end>
#
# Epoch 120 Loss 0.6969
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > je vous de cela cela tous les . <end>
#
# Epoch 121 Loss 0.7920
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee vous une autre chance ? <end>
#
# Epoch 122 Loss 0.8120
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment vous qu il il il la agit agit d un piege ? <end>
#
# Epoch 123 Loss 0.8732
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 124 Loss 0.6663
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous de m excuser ! vous parler ? <end>
#
# Epoch 125 Loss 0.5975
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > vous la la les . <end>
#
# Epoch 126 Loss 0.6897
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 127 Loss 0.6097
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous de m excuser ! savez vous ? <end>
#
# Epoch 128 Loss 0.8063
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne pas abuser par les . <end>
#
# Epoch 129 Loss 0.7285
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 130 Loss 0.5495
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > je de que vous cela veut . <end>
#
# Epoch 131 Loss 0.7334
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 132 Loss 0.7837
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 133 Loss 0.5469
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > n n pas pas folle . <end>
#
# Epoch 134 Loss 0.5190
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous de m excuser ! savez vous ? <end>
#
# Epoch 135 Loss 0.6827
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > ce vous qu il la la agit d un <end>
#
# Epoch 136 Loss 0.6700
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment vous qu il il il la agit agit d un piege ? <end>
#
# Epoch 137 Loss 0.5197
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous qu il il la la agit d un <end>
#
# Epoch 138 Loss 0.4835
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne pas abuser par les . <end>
#
# Epoch 139 Loss 0.7152
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > il il est s s possedait l endroit . <end>
#
# Epoch 140 Loss 0.4792
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 141 Loss 0.4312
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 142 Loss 0.5753
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 143 Loss 0.5248
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 144 Loss 0.5692
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > il est est s s possedait l . <end>
#
# Epoch 145 Loss 0.3803
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 146 Loss 0.4726
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > n n pas pas folle . <end>
#
# Epoch 147 Loss 0.3251
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment vous qu il il il la agit pas d un piege ? <end>
#
# Epoch 148 Loss 0.4213
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les . <end>
#
# Epoch 149 Loss 0.4379
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les . <end>
#
# Epoch 150 Loss 0.3685
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 151 Loss 0.3291
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des ? <end>
#
# Epoch 152 Loss 0.4187
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il il ne agit pas d un piege ? <end>
#
# Epoch 153 Loss 0.4713
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 154 Loss 0.4555
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 155 Loss 0.4050
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 156 Loss 0.3435
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 157 Loss 0.5212
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 158 Loss 0.4036
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous fermer la s s il ? <end>
#
# Epoch 159 Loss 0.4558
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a longue . <end>
#
# Epoch 160 Loss 0.3798
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 161 Loss 0.2913
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 162 Loss 0.2861
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous fermer la s s il ? <end>
#
# Epoch 163 Loss 0.3766
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 164 Loss 0.3519
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > il est est s s possedait l endroit . <end>
#
# Epoch 165 Loss 0.4251
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des ? <end>
#
# Epoch 166 Loss 0.3544
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 167 Loss 0.4702
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous prie de m excuser ! savez vous parler anglais ? <end>
#
# Epoch 168 Loss 0.4611
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 169 Loss 0.4141
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous prie de m excuser ! vous parler anglais ? <end>
#
# Epoch 170 Loss 0.3328
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 171 Loss 0.3167
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 172 Loss 0.3659
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 173 Loss 0.4408
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 174 Loss 0.2403
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 175 Loss 0.3203
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des ? <end>
#
# Epoch 176 Loss 0.3417
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 177 Loss 0.3021
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > je de ce que cela veut reellement dire . <end>
#
# Epoch 178 Loss 0.3234
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 179 Loss 0.3075
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 180 Loss 0.2906
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 181 Loss 0.2682
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 182 Loss 0.2616
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > n est pas completement folle . <end>
#
# Epoch 183 Loss 0.2558
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 184 Loss 0.2481
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > votre n est pas completement folle . <end>
#
# Epoch 185 Loss 0.2885
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 186 Loss 0.2974
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > l honnetete a la longue . <end>
#
# Epoch 187 Loss 0.2906
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 188 Loss 0.2253
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > il est comporte comme s il possedait l endroit . <end>
#
# Epoch 189 Loss 0.3837
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > il est comporte comme s il possedait l endroit . <end>
#
# Epoch 190 Loss 0.2643
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > ce vous qu il la la agit d ? <end>
#
# Epoch 191 Loss 0.2695
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 192 Loss 0.2842
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 193 Loss 0.2360
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > ce vous qu il la la agit d un <end>
#
# Epoch 194 Loss 0.2704
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > votre n est pas completement folle . <end>
#
# Epoch 195 Loss 0.1854
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous prie de m excuser ! savez vous ? <end>
#
# Epoch 196 Loss 0.2331
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 197 Loss 0.2659
# < What a ridiculous concept !
# = Quel concept ridicule !
# > l a . <end>
#
# Epoch 198 Loss 0.1975
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 199 Loss 0.2293
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a la longue . <end>
#
# Epoch 200 Loss 0.1787
# < What a ridiculous concept !
# = Quel concept ridicule !
# > l a . <end>
#
# Epoch 201 Loss 0.1976
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > l honnetete a la longue . <end>
#
# Epoch 202 Loss 0.1507
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous prie de m excuser ! savez vous ? <end>
#
# Epoch 203 Loss 0.2256
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des <end>
#
# Epoch 204 Loss 0.1502
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 205 Loss 0.2512
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne vous pas par les apparences . <end>
#
# Epoch 206 Loss 0.1916
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > vous qu la la d un <end>
#
# Epoch 207 Loss 0.2228
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 208 Loss 0.2421
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a la longue . <end>
#
# Epoch 209 Loss 0.2783
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne vous pas par les apparences . <end>
#
# Epoch 210 Loss 0.2365
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 211 Loss 0.2153
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > votre n est pas completement folle . <end>
#
# Epoch 212 Loss 0.1832
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des <end>
#
# Epoch 213 Loss 0.1883
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne vous pas par les apparences . <end>
#
# Epoch 214 Loss 0.2326
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de c est l anniversaire aujourd hui <end>
#
# Epoch 215 Loss 0.1480
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des ? <end>
#
# Epoch 216 Loss 0.1416
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 217 Loss 0.1872
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne vous pas par les apparences . <end>
#
# Epoch 218 Loss 0.1290
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 219 Loss 0.1553
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > l honnetete a la longue . <end>
#
# Epoch 220 Loss 0.1573
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de c est l anniversaire aujourd hui <end>
#
# Epoch 221 Loss 0.1351
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 222 Loss 0.1334
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 223 Loss 0.1408
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des <end>
#
# Epoch 224 Loss 0.1249
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 225 Loss 0.1326
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > votre n est pas completement folle . <end>
#
# Epoch 226 Loss 0.1702
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 227 Loss 0.1895
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 228 Loss 0.1563
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > l honnetete a la longue . <end>
#
# Epoch 229 Loss 0.1192
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 230 Loss 0.1610
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 231 Loss 0.1601
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 232 Loss 0.1254
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous prie de m excuser ! savez vous ? <end>
#
# Epoch 233 Loss 0.1050
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 234 Loss 0.1209
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des <end>
#
# Epoch 235 Loss 0.1360
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > je vous de m excuser ! savez vous ? <end>
#
# Epoch 236 Loss 0.1335
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce que cela veut reellement dire . <end>
#
# Epoch 237 Loss 0.1040
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > l honnetete a la longue . <end>
#
# Epoch 238 Loss 0.1750
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > l honnetete a la longue . <end>
#
# Epoch 239 Loss 0.1476
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de c est l anniversaire aujourd hui ! <end>
#
# Epoch 240 Loss 0.1656
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 241 Loss 0.0991
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > ce qu il est tres mal . <end>
#
# Epoch 242 Loss 0.1328
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > ce qu il est tres mal . <end>
#
# Epoch 243 Loss 0.1395
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > ce qu il est tres mal . <end>
#
# Epoch 244 Loss 0.0982
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 245 Loss 0.1526
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles ? <end>
#
# Epoch 246 Loss 0.1284
# < All three of you need to do that .
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois . <end>
#
# Epoch 247 Loss 0.0849
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des <end>
#
# Epoch 248 Loss 0.1575
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 249 Loss 0.1347
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de c est l anniversaire aujourd hui ! <end>
#
# Epoch 250 Loss 0.1316
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce que cela veut reellement dire . <end>
#
# Epoch 251 Loss 0.1099
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des <end>
#
# Epoch 252 Loss 0.1000
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 253 Loss 0.0834
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > je vous de m excuser ! savez vous ? <end>
#
# Epoch 254 Loss 0.1373
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > ce qu il est tres mal . <end>
#
# Epoch 255 Loss 0.1472
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce que cela veut reellement dire . <end>
#
# Epoch 256 Loss 0.1057
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 257 Loss 0.0691
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 258 Loss 0.0920
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 259 Loss 0.0888
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a la longue . <end>
#
# Epoch 260 Loss 0.1437
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 261 Loss 0.0765
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles ? <end>
#
# Epoch 262 Loss 0.0823
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > ce qu il est tres mal . <end>
#
# Epoch 263 Loss 0.1389
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des <end>
#
# Epoch 264 Loss 0.0787
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de c est l anniversaire aujourd hui ! <end>
#
# Epoch 265 Loss 0.1169
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > je avoir quelques minutes je vous prie ? <end>
#
# Epoch 266 Loss 0.0830
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > ce qu il est tres mal . <end>
#
# Epoch 267 Loss 0.0920
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 268 Loss 0.1277
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 269 Loss 0.1020
# < Could you close the door please ?
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > je vous prie de excuser ! <end>
#
# Epoch 270 Loss 0.1038
# < Did you plant pumpkins this year ?
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles ? <end>
#
# Epoch 271 Loss 0.0678
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce que cela veut reellement dire . <end>
#
# Epoch 272 Loss 0.0976
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne vous laissez pas par les apparences . <end>
#
# Epoch 273 Loss 0.0916
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me vous une autre chance ? <end>
#
# Epoch 274 Loss 0.1315
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de ce que cela veut reellement dire . <end>
#
# Epoch 275 Loss 0.0722
# < Honesty will pay in the long run .
# = L'honnêteté paye à la longue.
# > l honnetete paye a la longue . <end>
#
# Epoch 276 Loss 0.1050
# < Your idea is not entirely crazy .
# = Votre idée n'est pas complètement folle.
# > votre n est pas completement folle . <end>
#
# Epoch 277 Loss 0.0747
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 278 Loss 0.0842
# < How do we know this isn t a trap ?
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege ? <end>
#
# Epoch 279 Loss 0.0753
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a la longue . <end>
#
# Epoch 280 Loss 0.0955
# < Guess whose birthday it is today .
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de c est l anniversaire aujourd hui ! <end>
#
# Epoch 281 Loss 0.0967
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 282 Loss 0.1095
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 283 Loss 0.0857
# < Both Tom and Mary work as models .
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent tous les deux comme mannequins . <end>
#
# Epoch 284 Loss 0.0604
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > ce qu il est tres mal . <end>
#
# Epoch 285 Loss 0.0940
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce que cela veut reellement dire . <end>
#
# Epoch 286 Loss 0.1045
# < Germany produced many scientists .
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a la longue . <end>
#
# Epoch 287 Loss 0.0587
# < I can t believe you re giving up .
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez . <end>
#
# Epoch 288 Loss 0.0693
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous ? <end>
#
# Epoch 289 Loss 0.0702
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 290 Loss 0.1063
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s est comporte comme s il possedait <end>
#
# Epoch 291 Loss 0.0878
# < Few people know the true meaning .
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce que cela veut reellement dire . <end>
#
# Epoch 292 Loss 0.0831
# < What he did is very wrong .
# = Ce qu'il a fait est très mal.
# > ce qu il est tres mal . <end>
#
# Epoch 293 Loss 0.0685
# < Excuse me . Can you speak English ?
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous prie de m excuser ! savez vous parler <end>
#
# Epoch 294 Loss 0.0673
# < Are you giving me another chance ?
# = Me donnez-vous une autre chance ?
# > me donnez vous autre chance ? <end>
#
# Epoch 295 Loss 0.0894
# < A man s worth lies in what he is .
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est . <end>
#
# Epoch 296 Loss 0.0610
# < Can I have a few minutes please ?
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous prie ? <end>
#
# Epoch 297 Loss 0.0536
# < Don t be deceived by appearances .
# = Ne vous laissez pas abuser par les apparences.
# > ne vous laissez pas par les apparences . <end>
#
# Epoch 298 Loss 0.0692
# < Do you ever study in the library ?
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# Epoch 299 Loss 0.0917
# < He acted like he owned the place .
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s est comporte comme s il possedait <end>
#
# Epoch 300 Loss 0.0741

# %%
test_sents = (
    'What a ridiculous concept!',
    'Your idea is not entirely crazy.',
    "A man's worth lies in what he is.",
    'What he did is very wrong.',
    "All three of you need to do that.",
    "Are you giving me another chance?",
    "Both Tom and Mary work as models.",
    "Can I have a few minutes, please?",
    "Could you close the door, please?",
    "Did you plant pumpkins this year?",
    "Do you ever study in the library?",
    "Don't be deceived by appearances.",
    "Excuse me. Can you speak English?",
    "Few people know the true meaning.",
    "Germany produced many scientists.",
    "Guess whose birthday it is today.",
    "He acted like he owned the place.",
    "Honesty will pay in the long run.",
    "How do we know this isn't a trap?",
    "I can't believe you're giving up.",
)

for test_sent in test_sents:
    test_sequence = normalize_string(test_sent)
    predict(test_sequence)
# Out:
# < What a ridiculous concept !
# > quel concept ridicule ! <end>
#
# < Your idea is not entirely crazy .
# > votre idee n est pas completement folle . <end>
#
# < A man s worth lies in what he is .
# > la valeur d un homme reside dans ce qu il est . <end>
#
# < What he did is very wrong .
# > ce qu il a fait est tres mal . <end>
#
# < All three of you need to do that .
# > vous avez besoin de faire cela tous les trois . <end>
#
# < Are you giving me another chance ?
# > me donnez vous une autre chance ? <end>
#
# < Both Tom and Mary work as models .
# > tom et mary travaillent tous les deux comme mannequins . <end>
#
# < Can I have a few minutes please ?
# > puis je avoir quelques minutes je vous prie ? <end>
#
# < Could you close the door please ?
# > pourriez vous fermer la porte s il vous plait ? <end>
#
# < Did you plant pumpkins this year ?
# > cette annee avez vous plante des citrouilles ? <end>
#
# < Do you ever study in the library ?
# > est ce que vous etudiez a la bibliotheque des fois ? <end>
#
# < Don t be deceived by appearances .
# > ne vous laissez pas abuser par les apparences . <end>
#
# < Excuse me . Can you speak English ?
# > je vous prie de m excuser ! savez vous parler anglais ? <end>
#
# < Few people know the true meaning .
# > peu de gens savent ce que cela veut reellement dire . <end>
#
# < Germany produced many scientists .
# > l allemagne a produit beaucoup . <end>
#
# < Guess whose birthday it is today .
# > devine de qui c est l anniversaire aujourd hui ! <end>
#
# < He acted like he owned the place .
# > il s est comporte comme s il possedait l endroit . <end>
#
# < Honesty will pay in the long run .
# > l honnetete paye a la longue . <end>
#
# < How do we know this isn t a trap ?
# > comment savez vous qu il ne s agit pas d un piege ? <end>
#
# < I can t believe you re giving up .
# > je n arrive pas a croire que vous abandonniez . <end>
