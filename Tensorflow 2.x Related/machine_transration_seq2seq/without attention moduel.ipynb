# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import os
import re
import unicodedata

# %%
raw_data = (
    ('What a ridiculous concept!', 'Quel concept ridicule !'),
    ('Your idea is not entirely crazy.', "Votre idée n'est pas complètement folle."),
    ("A man's worth lies in what he is.", "La valeur d'un homme réside dans ce qu'il est."),
    ('What he did is very wrong.', "Ce qu'il a fait est très mal."),
    ("All three of you need to do that.", "Vous avez besoin de faire cela, tous les trois."),
    ("Are you giving me another chance?", "Me donnez-vous une autre chance ?"),
    ("Both Tom and Mary work as models.", "Tom et Mary travaillent tous les deux comme mannequins."),
    ("Can I have a few minutes, please?", "Puis-je avoir quelques minutes, je vous prie ?"),
    ("Could you close the door, please?", "Pourriez-vous fermer la porte, s'il vous plaît ?"),
    ("Did you plant pumpkins this year?", "Cette année, avez-vous planté des citrouilles ?"),
    ("Do you ever study in the library?", "Est-ce que vous étudiez à la bibliothèque des fois ?"),
    ("Don't be deceived by appearances.", "Ne vous laissez pas abuser par les apparences."),
    ("Excuse me. Can you speak English?", "Je vous prie de m'excuser ! Savez-vous parler anglais ?"),
    ("Few people know the true meaning.", "Peu de gens savent ce que cela veut réellement dire."),
    ("Germany produced many scientists.", "L'Allemagne a produit beaucoup de scientifiques."),
    ("Guess whose birthday it is today.", "Devine de qui c'est l'anniversaire, aujourd'hui !"),
    ("He acted like he owned the place.", "Il s'est comporté comme s'il possédait l'endroit."),
    ("Honesty will pay in the long run.", "L'honnêteté paye à la longue."),
    ("How do we know this isn't a trap?", "Comment savez-vous qu'il ne s'agit pas d'un piège ?"),
    ("I can't believe you're giving up.", "Je n'arrive pas à croire que vous abandonniez."),
)

# %%
def unicode_to_ascii(sentence):
  return ''.join(char for char in unicodedata.normalize('NFD', sentence) if unicodedata.category(char) != 'Mn')

# %%
def normalize_string(sentence):
  s = unicode_to_ascii(sentence.lower())
  s = re.sub(r'([!.?])', r' \1 ', s)
  s = re.sub(r'[^a-zA-Z]+', ' ', s)
  s = re.sub('\s+', ' ', s)
  # s = '<start> ' + s + ' <end>'
  return s

# %%
df = pd.DataFrame(raw_data)
df.columns = ['eng', 'fra']

# %%
df.head()
# Out:
#                                  eng                                              fra
# 0         What a ridiculous concept!                          Quel concept ridicule !
# 1   Your idea is not entirely crazy.         Votre idée n'est pas complètement folle.
# 2  A man's worth lies in what he is.   La valeur d'un homme réside dans ce qu'il est.
# 3         What he did is very wrong.                    Ce qu'il a fait est très mal.
# 4  All three of you need to do that.  Vous avez besoin de faire cela, tous les trois.

# %%
df['eng'] = df['eng'].apply(normalize_string)
df['fra'] = df['fra'].apply(normalize_string)

# %%
df.head()
# Out:
#                                                eng                                                fra
# 0         <start> what a ridiculous concept  <end>               <start> quel concept ridicule  <end>
# 1   <start> your idea is not entirely crazy  <end>  <start> votre idee n est pas completement foll...
# 2  <start> a man s worth lies in what he is  <end>  <start> la valeur d un homme reside dans ce qu...
# 3         <start> what he did is very wrong  <end>        <start> ce qu il a fait est tres mal  <end>
# 4  <start> all three of you need to do that  <end>  <start> vous avez besoin de faire cela tous le...

# %%
raw_data_en, raw_data_fr = list(zip(*raw_data))
raw_data_en, raw_data_fr = list(raw_data_en), list(raw_data_fr)
raw_data_en = [normalize_string(data) for data in raw_data_en]
raw_data_fr_in = ['<start> ' + normalize_string(data) for data in raw_data_fr]
raw_data_fr_out = [normalize_string(data) + ' <end>' for data in raw_data_fr]

# %%
raw_data_en
# Out:
# ['what a ridiculous concept ',
#  'your idea is not entirely crazy ',
#  'a man s worth lies in what he is ',
#  'what he did is very wrong ',
#  'all three of you need to do that ',
#  'are you giving me another chance ',
#  'both tom and mary work as models ',
#  'can i have a few minutes please ',
#  'could you close the door please ',
#  'did you plant pumpkins this year ',
#  'do you ever study in the library ',
#  'don t be deceived by appearances ',
#  'excuse me can you speak english ',
#  'few people know the true meaning ',
#  'germany produced many scientists ',
#  'guess whose birthday it is today ',
#  'he acted like he owned the place ',
#  'honesty will pay in the long run ',
#  'how do we know this isn t a trap ',
#  'i can t believe you re giving up ']

# %%
raw_data_fr_in
# Out:
# ['<start> quel concept ridicule ',
#  '<start> votre idee n est pas completement folle ',
#  '<start> la valeur d un homme reside dans ce qu il est ',
#  '<start> ce qu il a fait est tres mal ',
#  '<start> vous avez besoin de faire cela tous les trois ',
#  '<start> me donnez vous une autre chance ',
#  '<start> tom et mary travaillent tous les deux comme mannequins ',
#  '<start> puis je avoir quelques minutes je vous prie ',
#  '<start> pourriez vous fermer la porte s il vous plait ',
#  '<start> cette annee avez vous plante des citrouilles ',
#  '<start> est ce que vous etudiez a la bibliotheque des fois ',
#  '<start> ne vous laissez pas abuser par les apparences ',
#  '<start> je vous prie de m excuser savez vous parler anglais ',
#  '<start> peu de gens savent ce que cela veut reellement dire ',
#  '<start> l allemagne a produit beaucoup de scientifiques ',
#  '<start> devine de qui c est l anniversaire aujourd hui ',
#  '<start> il s est comporte comme s il possedait l endroit ',
#  '<start> l honnetete paye a la longue ',
#  '<start> comment savez vous qu il ne s agit pas d un piege ',
#  '<start> je n arrive pas a croire que vous abandonniez ']

# %%
raw_data_fr_out
# Out:
# ['quel concept ridicule  <end>',
#  'votre idee n est pas completement folle  <end>',
#  'la valeur d un homme reside dans ce qu il est  <end>',
#  'ce qu il a fait est tres mal  <end>',
#  'vous avez besoin de faire cela tous les trois  <end>',
#  'me donnez vous une autre chance  <end>',
#  'tom et mary travaillent tous les deux comme mannequins  <end>',
#  'puis je avoir quelques minutes je vous prie  <end>',
#  'pourriez vous fermer la porte s il vous plait  <end>',
#  'cette annee avez vous plante des citrouilles  <end>',
#  'est ce que vous etudiez a la bibliotheque des fois  <end>',
#  'ne vous laissez pas abuser par les apparences  <end>',
#  'je vous prie de m excuser savez vous parler anglais  <end>',
#  'peu de gens savent ce que cela veut reellement dire  <end>',
#  'l allemagne a produit beaucoup de scientifiques  <end>',
#  'devine de qui c est l anniversaire aujourd hui  <end>',
#  'il s est comporte comme s il possedait l endroit  <end>',
#  'l honnetete paye a la longue  <end>',
#  'comment savez vous qu il ne s agit pas d un piege  <end>',
#  'je n arrive pas a croire que vous abandonniez  <end>']

# %%
en_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
en_tokenizer.fit_on_texts(raw_data_en)
data_en = en_tokenizer.texts_to_sequences(raw_data_en)
data_en = tf.keras.preprocessing.sequence.pad_sequences(data_en, padding='post')

fr_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
fr_tokenizer.fit_on_texts(raw_data_fr_in)
fr_tokenizer.fit_on_texts(raw_data_fr_out)
data_fr_in = fr_tokenizer.texts_to_sequences(raw_data_fr_in)
data_fr_in = tf.keras.preprocessing.sequence.pad_sequences(data_fr_in,  padding='post')

data_fr_out = fr_tokenizer.texts_to_sequences(raw_data_fr_out)
data_fr_out = tf.keras.preprocessing.sequence.pad_sequences(data_fr_out, padding='post')


BATCH_SIZE = 5
dataset = tf.data.Dataset.from_tensor_slices(
    (data_en, data_fr_in, data_fr_out))
dataset = dataset.shuffle(20).batch(BATCH_SIZE)

# %%
raw_data_en[0], raw_data_fr[0]
# Out:
# ('what a ridiculous concept ', 'Quel concept ridicule !')

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, lstm_size):
        super(Encoder, self).__init__()
        self.lstm_size = lstm_size
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.lstm = tf.keras.layers.LSTM(
            lstm_size, return_sequences=True, return_state=True)

    def call(self, sequence, states):
        embed = self.embedding(sequence)
        output, state_h, state_c = self.lstm(embed, initial_state=states)

        return output, state_h, state_c

    def init_states(self, batch_size):
        return (tf.zeros([batch_size, self.lstm_size]),
                tf.zeros([batch_size, self.lstm_size]))


class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, lstm_size):
        super(Decoder, self).__init__()
        self.lstm_size = lstm_size
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.lstm = tf.keras.layers.LSTM(
            lstm_size, return_sequences=True, return_state=True)
        self.dense = tf.keras.layers.Dense(vocab_size)

    def call(self, sequence, state):
        embed = self.embedding(sequence)
        lstm_out, state_h, state_c = self.lstm(embed, state)
        logits = self.dense(lstm_out)

        return logits, state_h, state_c

    def init_states(self, batch_size):
        return (tf.zeros([batch_size, self.lstm_size]),
                tf.zeros([batch_size, self.lstm_size]))

# %%
en_vocab_size = len(en_tokenizer.word_index) + 1
fr_vocab_size = len(fr_tokenizer.word_index) + 1

EMBEDDING_SIZE = 32
LSTM_SIZE = 64

encoder = Encoder(en_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)
decoder = Decoder(fr_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)

initial_states = encoder.init_states(1)
encoder_outputs = encoder(tf.constant([[1, 2, 3]]), initial_states)
decoder_outputs = decoder(tf.constant([[1, 2, 3]]), encoder_outputs[1:])

# %%
def loss_func(targets, logits):
    crossentropy = tf.keras.losses.SparseCategoricalCrossentropy(
        from_logits=True)
    mask = tf.math.logical_not(tf.math.equal(targets, 0))
    mask = tf.cast(mask, dtype=tf.int64)
    loss = crossentropy(targets, logits, sample_weight=mask)

    return loss


optimizer = tf.keras.optimizers.Adam()


def predict(test_source_text=None):
    if test_source_text is None:
        r = np.random.choice(len(raw_data_en))
        test_source_text = raw_data_en[r]
        test_target_text = raw_data_fr[r]
    else:
        test_target_text = None
    print('<',test_source_text)
    
    if test_target_text is not None:
      print('=',test_target_text)
      
    test_source_seq = en_tokenizer.texts_to_sequences([test_source_text])
    #print(test_source_seq)

    en_initial_states = encoder.init_states(1)
    en_outputs = encoder(tf.constant(test_source_seq), en_initial_states)

    de_input = tf.constant([[fr_tokenizer.word_index['<start>']]])
    de_state_h, de_state_c = en_outputs[1:]
    out_words = []

    while True:
        de_output, de_state_h, de_state_c = decoder(
            de_input, (de_state_h, de_state_c))
        de_input = tf.argmax(de_output, -1)
        out_words.append(fr_tokenizer.index_word[de_input.numpy()[0][0]])

        if out_words[-1] == '<end>' or len(out_words) >= 20:
            break

    print('>',' '.join(out_words))
    print()


@tf.function
def train_step(source_seq, target_seq_in, target_seq_out, en_initial_states):
    loss = 0
    with tf.GradientTape() as tape:
        en_outputs = encoder(source_seq, en_initial_states)
        en_states = en_outputs[1:]
        de_states = en_states

        de_outputs = decoder(target_seq_in, de_states)
        logits = de_outputs[0]
        loss = loss_func(target_seq_out, logits)

    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return loss

# %%
NUM_EPOCHS = 300

for e in range(NUM_EPOCHS):
    en_initial_states = encoder.init_states(BATCH_SIZE)
    
    predict()

    for batch, (source_seq, target_seq_in, target_seq_out) in enumerate(dataset.take(-1)):
        loss = train_step(source_seq, target_seq_in,
                          target_seq_out, en_initial_states)

    print('Epoch {} Loss {:.4f}'.format(e + 1, loss.numpy()))
# Out:
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > savez qu reside prie d comme deux piege plait plait plait paye paye paye parler parler beaucoup beaucoup croire reside
#
# Epoch 1 Loss 3.3065
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > vous est <end>
#
# Epoch 2 Loss 3.5881
# < what a ridiculous concept
# = Quel concept ridicule !
# > <end>
#
# Epoch 3 Loss 3.5111
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous <end>
#
# Epoch 4 Loss 3.2887
# < what a ridiculous concept
# = Quel concept ridicule !
# > <end>
#
# Epoch 5 Loss 2.7818
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous vous <end>
#
# Epoch 6 Loss 3.3332
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > vous <end>
#
# Epoch 7 Loss 3.8470
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > vous <end>
#
# Epoch 8 Loss 3.2541
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > vous <end>
#
# Epoch 9 Loss 2.8950
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous <end>
#
# Epoch 10 Loss 3.1111
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > vous <end>
#
# Epoch 11 Loss 2.9572
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous <end>
#
# Epoch 12 Loss 3.1698
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > vous vous vous <end>
#
# Epoch 13 Loss 3.1363
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous vous vous <end>
#
# Epoch 14 Loss 2.8644
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > vous vous vous vous vous <end>
#
# Epoch 15 Loss 2.2480
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > vous vous vous vous <end>
#
# Epoch 16 Loss 3.2807
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > vous vous vous <end>
#
# Epoch 17 Loss 3.3205
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous vous vous <end>
#
# Epoch 18 Loss 2.9710
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > vous vous vous vous vous <end>
#
# Epoch 19 Loss 2.7016
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > vous vous vous vous <end>
#
# Epoch 20 Loss 2.4962
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > vous vous vous vous <end>
#
# Epoch 21 Loss 2.8690
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous vous vous vous <end>
#
# Epoch 22 Loss 2.8379
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > vous vous vous <end>
#
# Epoch 23 Loss 2.9641
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > vous vous vous <end>
#
# Epoch 24 Loss 2.8464
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > vous vous vous <end>
#
# Epoch 25 Loss 2.7043
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > vous vous vous vous <end>
#
# Epoch 26 Loss 2.3542
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous vous vous vous vous <end>
#
# Epoch 27 Loss 3.0113
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > vous vous vous vous vous <end>
#
# Epoch 28 Loss 2.4361
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > vous vous vous vous <end>
#
# Epoch 29 Loss 2.7006
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > vous vous vous vous vous <end>
#
# Epoch 30 Loss 2.4015
# < what a ridiculous concept
# = Quel concept ridicule !
# > ce que vous <end>
#
# Epoch 31 Loss 2.6304
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > vous vous vous vous <end>
#
# Epoch 32 Loss 2.2578
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > vous vous vous vous vous <end>
#
# Epoch 33 Loss 2.6522
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > <end>
#
# Epoch 34 Loss 2.6010
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous vous vous vous <end>
#
# Epoch 35 Loss 2.8431
# < what a ridiculous concept
# = Quel concept ridicule !
# > ce est est <end>
#
# Epoch 36 Loss 2.5025
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous vous vous <end>
#
# Epoch 37 Loss 2.1002
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous vous vous vous vous <end>
#
# Epoch 38 Loss 2.5181
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous vous vous vous <end>
#
# Epoch 39 Loss 2.1771
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous a vous vous <end>
#
# Epoch 40 Loss 2.2102
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > vous vous vous vous <end>
#
# Epoch 41 Loss 2.4042
# < what a ridiculous concept
# = Quel concept ridicule !
# > <end>
#
# Epoch 42 Loss 2.2018
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous vous vous les <end>
#
# Epoch 43 Loss 2.3909
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > ce vous vous a <end>
#
# Epoch 44 Loss 1.9720
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > vous vous vous vous <end>
#
# Epoch 45 Loss 2.4919
# < what a ridiculous concept
# = Quel concept ridicule !
# > <end>
#
# Epoch 46 Loss 2.2034
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous vous vous vous vous <end>
#
# Epoch 47 Loss 2.4122
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous vous vous des <end>
#
# Epoch 48 Loss 2.2041
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > <end>
#
# Epoch 49 Loss 2.1839
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l vous <end>
#
# Epoch 50 Loss 1.9634
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > vous vous vous la <end>
#
# Epoch 51 Loss 2.1973
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > vous vous vous vous <end>
#
# Epoch 52 Loss 2.0538
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > je vous vous vous <end>
#
# Epoch 53 Loss 1.9584
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous vous vous vous vous <end>
#
# Epoch 54 Loss 1.7890
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > vous vous vous des <end>
#
# Epoch 55 Loss 1.9756
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > vous vous vous a a des <end>
#
# Epoch 56 Loss 1.6445
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > <end>
#
# Epoch 57 Loss 1.5042
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous vous vous vous vous des <end>
#
# Epoch 58 Loss 1.6421
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l a a la <end>
#
# Epoch 59 Loss 1.6581
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > je vous vous vous vous <end>
#
# Epoch 60 Loss 1.6793
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > je je vous vous vous vous <end>
#
# Epoch 61 Loss 1.5359
# < i can t believe you re giving up
# = Je n'arrive pas à croire que vous abandonniez.
# > je je de que que vous vous <end>
#
# Epoch 62 Loss 1.7203
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > je je vous vous vous <end>
#
# Epoch 63 Loss 1.4736
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > vous vous vous autre <end>
#
# Epoch 64 Loss 1.6350
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce est est <end>
#
# Epoch 65 Loss 1.5308
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > vous vous vous vous s s s vous vous <end>
#
# Epoch 66 Loss 1.4446
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous s s vous <end>
#
# Epoch 67 Loss 1.3622
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il il a a la d <end>
#
# Epoch 68 Loss 1.5783
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous vous vous des <end>
#
# Epoch 69 Loss 1.3378
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous vous vous vous vous <end>
#
# Epoch 70 Loss 1.5704
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous vous vous des <end>
#
# Epoch 71 Loss 1.5337
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > je vous vous vous des <end>
#
# Epoch 72 Loss 1.2955
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom mary mary tous les les <end>
#
# Epoch 73 Loss 1.2767
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous vous abuser les <end>
#
# Epoch 74 Loss 1.3676
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > valeur valeur reside dans dans qu qu il est <end>
#
# Epoch 75 Loss 1.2876
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez de vous cela tous les <end>
#
# Epoch 76 Loss 1.3479
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il il a a la d <end>
#
# Epoch 77 Loss 1.3827
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous vous abuser les <end>
#
# Epoch 78 Loss 1.0155
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous vous vous vous des <end>
#
# Epoch 79 Loss 1.1346
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > je de que vous vous <end>
#
# Epoch 80 Loss 1.1376
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l a a la <end>
#
# Epoch 81 Loss 1.0040
# < what a ridiculous concept
# = Quel concept ridicule !
# > valeur valeur reside reside qu qu il est <end>
#
# Epoch 82 Loss 1.1928
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous s s vous <end>
#
# Epoch 83 Loss 1.2796
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > vous avez vous des <end>
#
# Epoch 84 Loss 1.1015
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l a la la <end>
#
# Epoch 85 Loss 1.1206
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > vous vous vous qu s s il il d un <end>
#
# Epoch 86 Loss 1.3279
# < what a ridiculous concept
# = Quel concept ridicule !
# > valeur valeur reside reside qu qu il est est <end>
#
# Epoch 87 Loss 1.1011
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce est est <end>
#
# Epoch 88 Loss 1.0105
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a scientifiques <end>
#
# Epoch 89 Loss 1.0238
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce est est <end>
#
# Epoch 90 Loss 0.8995
# < what a ridiculous concept
# = Quel concept ridicule !
# > valeur valeur homme reside qu qu il est est <end>
#
# Epoch 91 Loss 1.0659
# < i can t believe you re giving up
# = Je n'arrive pas à croire que vous abandonniez.
# > je n n pas a croire vous abandonniez <end>
#
# Epoch 92 Loss 0.7564
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 93 Loss 1.1489
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > n pas pas completement folle <end>
#
# Epoch 94 Loss 1.1839
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > vous avez vous des <end>
#
# Epoch 95 Loss 0.9224
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l a la la <end>
#
# Epoch 96 Loss 0.9200
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > vous de que vous cela les <end>
#
# Epoch 97 Loss 1.0287
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a scientifiques <end>
#
# Epoch 98 Loss 0.6757
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > vous avez plante des <end>
#
# Epoch 99 Loss 0.5760
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > vous vous fermer qu s s il il d un piege <end>
#
# Epoch 100 Loss 1.0514
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > je je je vous vous vous <end>
#
# Epoch 101 Loss 0.8075
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > ce vous a a a la des fois <end>
#
# Epoch 102 Loss 0.9740
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce est est <end>
#
# Epoch 103 Loss 0.6580
# < what a ridiculous concept
# = Quel concept ridicule !
# > valeur d homme reside ce qu est est <end>
#
# Epoch 104 Loss 0.7831
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous porte s il plait <end>
#
# Epoch 105 Loss 0.8572
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > vous avez plante des <end>
#
# Epoch 106 Loss 0.7990
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous vous abuser des citrouilles <end>
#
# Epoch 107 Loss 0.7323
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous des <end>
#
# Epoch 108 Loss 0.8804
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous des <end>
#
# Epoch 109 Loss 0.6306
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > je je je vous vous vous des <end>
#
# Epoch 110 Loss 0.8337
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom mary travaillent tous les deux mannequins <end>
#
# Epoch 111 Loss 0.6882
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de qui l anniversaire aujourd hui <end>
#
# Epoch 112 Loss 0.5704
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous vous porte s il plait <end>
#
# Epoch 113 Loss 0.5297
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > n est pas completement folle <end>
#
# Epoch 114 Loss 0.6177
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce est est <end>
#
# Epoch 115 Loss 0.8120
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l paye a la longue <end>
#
# Epoch 116 Loss 0.7193
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de que que vous reellement dire <end>
#
# Epoch 117 Loss 0.5834
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a des <end>
#
# Epoch 118 Loss 0.6085
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez de faire cela tous les trois <end>
#
# Epoch 119 Loss 0.5560
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > je je quelques minutes vous vous vous <end>
#
# Epoch 120 Loss 0.4816
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de que que vous reellement dire <end>
#
# Epoch 121 Loss 0.6000
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > vous vous fermer qu il s s il pas d un piege <end>
#
# Epoch 122 Loss 0.7253
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce est est <end>
#
# Epoch 123 Loss 0.5605
# < what a ridiculous concept
# = Quel concept ridicule !
# > valeur d homme dans ce qu est <end>
#
# Epoch 124 Loss 0.6329
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de qui l anniversaire aujourd hui <end>
#
# Epoch 125 Loss 0.4529
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous vous abuser par <end>
#
# Epoch 126 Loss 0.5492
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment vous qu il s il s il pas d un piege <end>
#
# Epoch 127 Loss 0.5670
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom mary travaillent tous les deux comme mannequins <end>
#
# Epoch 128 Loss 0.4887
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > il a fait mal <end>
#
# Epoch 129 Loss 0.4040
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > je je quelques minutes vous vous prie <end>
#
# Epoch 130 Loss 0.4713
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s il s il possedait l endroit <end>
#
# Epoch 131 Loss 0.5118
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > je je quelques minutes vous vous prie <end>
#
# Epoch 132 Loss 0.4860
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a des <end>
#
# Epoch 133 Loss 0.5838
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > vous une autre chance <end>
#
# Epoch 134 Loss 0.4482
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire tous les trois <end>
#
# Epoch 135 Loss 0.4291
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s il s il possedait l endroit <end>
#
# Epoch 136 Loss 0.5286
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce vous etudiez a la bibliotheque des fois <end>
#
# Epoch 137 Loss 0.5836
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a des <end>
#
# Epoch 138 Loss 0.6516
# < what a ridiculous concept
# = Quel concept ridicule !
# > valeur d reside dans ce qu est <end>
#
# Epoch 139 Loss 0.4811
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > vous une autre chance <end>
#
# Epoch 140 Loss 0.4347
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce vous etudiez a la bibliotheque des fois <end>
#
# Epoch 141 Loss 0.3385
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous de m excuser vous parler anglais <end>
#
# Epoch 142 Loss 0.5536
# < what a ridiculous concept
# = Quel concept ridicule !
# > valeur d reside dans ce qu est <end>
#
# Epoch 143 Loss 0.3833
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom mary travaillent tous les deux comme mannequins <end>
#
# Epoch 144 Loss 0.4438
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > il a fait est <end>
#
# Epoch 145 Loss 0.5370
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a des <end>
#
# Epoch 146 Loss 0.4590
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent que cela veut reellement <end>
#
# Epoch 147 Loss 0.4068
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent que cela veut reellement <end>
#
# Epoch 148 Loss 0.5335
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est <end>
#
# Epoch 149 Loss 0.4589
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce vous etudiez a la bibliotheque des fois <end>
#
# Epoch 150 Loss 0.4867
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous des citrouilles <end>
#
# Epoch 151 Loss 0.3438
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire tous les trois <end>
#
# Epoch 152 Loss 0.4495
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire tous les trois <end>
#
# Epoch 153 Loss 0.3189
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire tous les trois <end>
#
# Epoch 154 Loss 0.3677
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous des citrouilles <end>
#
# Epoch 155 Loss 0.3487
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s il s il possedait l endroit <end>
#
# Epoch 156 Loss 0.4870
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me vous une autre <end>
#
# Epoch 157 Loss 0.3468
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment vous qu il ne s s il pas d un piege <end>
#
# Epoch 158 Loss 0.3949
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me vous une autre <end>
#
# Epoch 159 Loss 0.3548
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment vous qu il ne s s il pas d un piege <end>
#
# Epoch 160 Loss 0.3716
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 161 Loss 0.1907
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de qui est anniversaire aujourd hui <end>
#
# Epoch 162 Loss 0.3453
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous laissez abuser par <end>
#
# Epoch 163 Loss 0.3868
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me vous une autre chance <end>
#
# Epoch 164 Loss 0.4030
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege <end>
#
# Epoch 165 Loss 0.3297
# < i can t believe you re giving up
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez <end>
#
# Epoch 166 Loss 0.2666
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l paye a la longue <end>
#
# Epoch 167 Loss 0.2624
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l paye a la longue <end>
#
# Epoch 168 Loss 0.2460
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et travaillent tous les deux comme mannequins <end>
#
# Epoch 169 Loss 0.2510
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous laissez abuser par les <end>
#
# Epoch 170 Loss 0.3354
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me vous une autre chance <end>
#
# Epoch 171 Loss 0.3226
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 172 Loss 0.3373
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me vous une autre chance <end>
#
# Epoch 173 Loss 0.2570
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire tous les trois <end>
#
# Epoch 174 Loss 0.2024
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege <end>
#
# Epoch 175 Loss 0.2214
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous des citrouilles <end>
#
# Epoch 176 Loss 0.2994
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 177 Loss 0.3286
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 178 Loss 0.3603
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l paye a la longue <end>
#
# Epoch 179 Loss 0.2544
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 180 Loss 0.2897
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me une une autre chance <end>
#
# Epoch 181 Loss 0.2322
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s il s il possedait l endroit <end>
#
# Epoch 182 Loss 0.2777
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous fermer porte s il vous plait <end>
#
# Epoch 183 Loss 0.2374
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous de m excuser vous parler anglais <end>
#
# Epoch 184 Loss 0.1606
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez la bibliotheque des fois <end>
#
# Epoch 185 Loss 0.2148
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary tous les deux comme mannequins <end>
#
# Epoch 186 Loss 0.2479
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous laissez pas par les <end>
#
# Epoch 187 Loss 0.3251
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous <end>
#
# Epoch 188 Loss 0.2884
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a des <end>
#
# Epoch 189 Loss 0.2449
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me une une autre chance <end>
#
# Epoch 190 Loss 0.2228
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous de m excuser vous parler anglais <end>
#
# Epoch 191 Loss 0.2188
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous laissez pas par les <end>
#
# Epoch 192 Loss 0.1907
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 193 Loss 0.1934
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela les trois <end>
#
# Epoch 194 Loss 0.2150
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de qui est l aujourd hui <end>
#
# Epoch 195 Loss 0.2138
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 196 Loss 0.1337
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous des citrouilles <end>
#
# Epoch 197 Loss 0.1230
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 198 Loss 0.2148
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous prie de m excuser vous parler anglais <end>
#
# Epoch 199 Loss 0.1779
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 200 Loss 0.1562
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce qu est est tres <end>
#
# Epoch 201 Loss 0.2123
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est <end>
#
# Epoch 202 Loss 0.2564
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary tous les deux comme mannequins <end>
#
# Epoch 203 Loss 0.2447
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce qu est est tres <end>
#
# Epoch 204 Loss 0.2114
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > vous prie de m excuser vous parler anglais <end>
#
# Epoch 205 Loss 0.2346
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 206 Loss 0.1661
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 207 Loss 0.2068
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce cela veut reellement dire <end>
#
# Epoch 208 Loss 0.2114
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 209 Loss 0.1126
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de qui est l aujourd hui <end>
#
# Epoch 210 Loss 0.1452
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois <end>
#
# Epoch 211 Loss 0.1770
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l paye a la longue <end>
#
# Epoch 212 Loss 0.1731
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l paye a la longue <end>
#
# Epoch 213 Loss 0.1684
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 214 Loss 0.1804
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me une une autre chance <end>
#
# Epoch 215 Loss 0.1731
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce qu est est tres <end>
#
# Epoch 216 Loss 0.1508
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l paye a la longue <end>
#
# Epoch 217 Loss 0.1543
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 218 Loss 0.1702
# < i can t believe you re giving up
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez <end>
#
# Epoch 219 Loss 0.1369
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a bibliotheque des fois <end>
#
# Epoch 220 Loss 0.1453
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege <end>
#
# Epoch 221 Loss 0.1485
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 222 Loss 0.1409
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous fermer la porte s il vous <end>
#
# Epoch 223 Loss 0.1315
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous fermer la porte s il vous <end>
#
# Epoch 224 Loss 0.1637
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce cela veut reellement dire <end>
#
# Epoch 225 Loss 0.1134
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 226 Loss 0.1145
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 227 Loss 0.1500
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce qu est tres mal <end>
#
# Epoch 228 Loss 0.1149
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s est comme s il possedait l endroit <end>
#
# Epoch 229 Loss 0.0870
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a des fois <end>
#
# Epoch 230 Loss 0.1660
# < few people know the true meaning
# = Peu de gens savent ce que cela veut réellement dire.
# > peu de savent ce cela veut reellement dire <end>
#
# Epoch 231 Loss 0.1164
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous <end>
#
# Epoch 232 Loss 0.0993
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous fermer la porte s il vous <end>
#
# Epoch 233 Loss 0.1001
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me une une autre chance <end>
#
# Epoch 234 Loss 0.1025
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me une une autre chance <end>
#
# Epoch 235 Loss 0.1382
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 236 Loss 0.0931
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 237 Loss 0.1340
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 238 Loss 0.1231
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 239 Loss 0.1047
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce qu est fait est <end>
#
# Epoch 240 Loss 0.1269
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 241 Loss 0.1161
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous <end>
#
# Epoch 242 Loss 0.1388
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l paye a la longue <end>
#
# Epoch 243 Loss 0.0777
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a la <end>
#
# Epoch 244 Loss 0.0984
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous <end>
#
# Epoch 245 Loss 0.0887
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante citrouilles <end>
#
# Epoch 246 Loss 0.1031
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 247 Loss 0.1176
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de qui c est aujourd hui <end>
#
# Epoch 248 Loss 0.0874
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce qu est fait est <end>
#
# Epoch 249 Loss 0.0770
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 250 Loss 0.1175
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 251 Loss 0.0751
# < i can t believe you re giving up
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez <end>
#
# Epoch 252 Loss 0.1008
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles <end>
#
# Epoch 253 Loss 0.1056
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 254 Loss 0.1007
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des fois <end>
#
# Epoch 255 Loss 0.0876
# < what a ridiculous concept
# = Quel concept ridicule !
# > je vous <end>
#
# Epoch 256 Loss 0.1071
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous prie de m vous parler anglais <end>
#
# Epoch 257 Loss 0.0823
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > vous fermer la porte s il vous <end>
#
# Epoch 258 Loss 0.1088
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de qui c est l hui <end>
#
# Epoch 259 Loss 0.1039
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous prie de m vous parler anglais <end>
#
# Epoch 260 Loss 0.0818
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l honnetete paye a longue <end>
#
# Epoch 261 Loss 0.1224
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s est comporte comme s il possedait l <end>
#
# Epoch 262 Loss 0.0835
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l honnetete paye a longue <end>
#
# Epoch 263 Loss 0.0898
# < germany produced many scientists
# = L'Allemagne a produit beaucoup de scientifiques.
# > l a la <end>
#
# Epoch 264 Loss 0.0763
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles <end>
#
# Epoch 265 Loss 0.0654
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous <end>
#
# Epoch 266 Loss 0.0679
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous laissez pas abuser par <end>
#
# Epoch 267 Loss 0.1028
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 268 Loss 0.0669
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me une autre chance <end>
#
# Epoch 269 Loss 0.0838
# < i can t believe you re giving up
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez <end>
#
# Epoch 270 Loss 0.0752
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l honnetete paye a longue <end>
#
# Epoch 271 Loss 0.0927
# < what he did is very wrong
# = Ce qu'il a fait est très mal.
# > ce qu est fait est <end>
#
# Epoch 272 Loss 0.0828
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles <end>
#
# Epoch 273 Loss 0.0525
# < how do we know this isn t a trap
# = Comment savez-vous qu'il ne s'agit pas d'un piège ?
# > comment savez vous qu il ne s agit pas d un piege <end>
#
# Epoch 274 Loss 0.0998
# < could you close the door please
# = Pourriez-vous fermer la porte, s'il vous plaît ?
# > pourriez vous la porte s il vous <end>
#
# Epoch 275 Loss 0.0784
# < are you giving me another chance
# = Me donnez-vous une autre chance ?
# > me une autre chance <end>
#
# Epoch 276 Loss 0.0904
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles <end>
#
# Epoch 277 Loss 0.0944
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles <end>
#
# Epoch 278 Loss 0.0978
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est <end>
#
# Epoch 279 Loss 0.0717
# < excuse me can you speak english
# = Je vous prie de m'excuser ! Savez-vous parler anglais ?
# > je vous prie de m vous parler anglais <end>
#
# Epoch 280 Loss 0.0619
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles <end>
#
# Epoch 281 Loss 0.0666
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois <end>
#
# Epoch 282 Loss 0.0719
# < i can t believe you re giving up
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez <end>
#
# Epoch 283 Loss 0.0532
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous laissez pas abuser par <end>
#
# Epoch 284 Loss 0.0715
# < don t be deceived by appearances
# = Ne vous laissez pas abuser par les apparences.
# > vous laissez pas abuser par <end>
#
# Epoch 285 Loss 0.0766
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l honnetete paye a longue <end>
#
# Epoch 286 Loss 0.0638
# < he acted like he owned the place
# = Il s'est comporté comme s'il possédait l'endroit.
# > il s est comporte comme s il possedait l <end>
#
# Epoch 287 Loss 0.0745
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles <end>
#
# Epoch 288 Loss 0.0637
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l honnetete paye a longue <end>
#
# Epoch 289 Loss 0.0538
# < your idea is not entirely crazy
# = Votre idée n'est pas complètement folle.
# > idee n est pas folle <end>
#
# Epoch 290 Loss 0.0685
# < did you plant pumpkins this year
# = Cette année, avez-vous planté des citrouilles ?
# > annee avez vous plante des citrouilles <end>
#
# Epoch 291 Loss 0.0676
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 292 Loss 0.0437
# < do you ever study in the library
# = Est-ce que vous étudiez à la bibliothèque des fois ?
# > est ce que vous etudiez a la bibliotheque des fois <end>
#
# Epoch 293 Loss 0.0660
# < honesty will pay in the long run
# = L'honnêteté paye à la longue.
# > l honnetete paye a longue <end>
#
# Epoch 294 Loss 0.0588
# < can i have a few minutes please
# = Puis-je avoir quelques minutes, je vous prie ?
# > puis je avoir quelques minutes je vous <end>
#
# Epoch 295 Loss 0.0785
# < i can t believe you re giving up
# = Je n'arrive pas à croire que vous abandonniez.
# > je n arrive pas a croire que vous abandonniez <end>
#
# Epoch 296 Loss 0.0566
# < a man s worth lies in what he is
# = La valeur d'un homme réside dans ce qu'il est.
# > la valeur d un homme reside dans ce qu il est <end>
#
# Epoch 297 Loss 0.0699
# < both tom and mary work as models
# = Tom et Mary travaillent tous les deux comme mannequins.
# > tom et mary travaillent les deux comme mannequins <end>
#
# Epoch 298 Loss 0.0444
# < guess whose birthday it is today
# = Devine de qui c'est l'anniversaire, aujourd'hui !
# > devine de qui c est l hui <end>
#
# Epoch 299 Loss 0.0574
# < all three of you need to do that
# = Vous avez besoin de faire cela, tous les trois.
# > vous avez besoin de faire cela tous les trois <end>
#
# Epoch 300 Loss 0.0544
