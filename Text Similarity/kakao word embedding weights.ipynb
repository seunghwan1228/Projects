# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from io import StringIO
import os

# %%
# !pip install kor2vec

# %%
# !git clone https://github.com/SKTBrain/KoBERT.git
# Out:
# Cloning into 'KoBERT'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 42 (delta 17), reused 35 (delta 13), pack-reused 0
# Unpacking objects: 100% (42/42), done.

# %%
# !cd /content/KoBERT
# !pip install -r /content/KoBERT/requirements.txt
# !pip install /content/KoBERT/setup.py
# Out:
# ERROR: Invalid requirement: '/content/KoBERT/setup.py'
# Hint: It looks like a path. It does exist.

# %%
# !ls
# Out:
#  drive	 'ko.tar.gz?dl=0'			  sample_data
#  KoBERT  'open?id=0B0ZXk88koS2KbDhXdWg1Q2RydlU'

# %%
# !cd KoBERT

# %%
os.chdir('/content/KoBERT')

# %%
# !pip install .
# Out:
# Processing /content/KoBERT
# ...
#   Created wheel for kobert: filename=kobert-0.1-cp36-none-any.whl size=12304 sha256=8e9bd2d01d4fa97bbb99d7c5744310b336c35ed2b0b655ad8c4c543e2082720e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kmw5rlxb/wheels/d0/ca/3e/bd91a227ac542246f4e8f94ff2f7f12a1a1f0c5b77601bcccf
# Successfully built kobert
# ...

# %%
import torch

# %%
from kobert.pytorch_kobert import get_pytorch_kobert_model

# %%
model, vocab = get_pytorch_kobert_model()
# Out:
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]

# %%
model

# %%
all_encoder_layer, pooled_out = model()

# %%
# !pip install fasttext
# Out:
# ...
#      |████████████████████████████████| 61kB 2.9MB/s
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.1-cp36-cp36m-linux_x86_64.whl size=2386871 sha256=4d48d11f20a9e1f51b1b17c4ae963bb474577851b5d5ecf7dd46da97609e8b2b
#   Stored in directory: /root/.cache/pip/wheels/9f/f0/04/caa82c912aee89ce76358ff954f3f0729b7577c8ff23a292e3
# Successfully built fasttext
# ...

# %%
import fasttext

# %%
# !wget https://drive.google.com/open?id=1jHbjOcnaLourFzNuP47yGQVhBTq6Wgor
# Out:
# --2019-09-26 01:41:28--  https://drive.google.com/open?id=1jHbjOcnaLourFzNuP47yGQVhBTq6Wgor
# Resolving drive.google.com (drive.google.com)... 108.177.112.100, 108.177.112.139, 108.177.112.138, ...
# Connecting to drive.google.com (drive.google.com)|108.177.112.100|:443... connected.
# HTTP request sent, awaiting response... 307 OK
# Location: https://drive.google.com/file/d/1jHbjOcnaLourFzNuP47yGQVhBTq6Wgor/view?usp=drive_open [following]
# --2019-09-26 01:41:28--  https://drive.google.com/file/d/1jHbjOcnaLourFzNuP47yGQVhBTq6Wgor/view?usp=drive_open
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘open?id=1jHbjOcnaLourFzNuP47yGQVhBTq6Wgor’
#
# open?id=1jHbjOcnaLo     [ <=>                ]  65.67K  --.-KB/s    in 0.003s
#
# 2019-09-26 01:41:28 (21.2 MB/s) - ‘open?id=1jHbjOcnaLourFzNuP47yGQVhBTq6Wgor’ saved [67249]

# %%
model_ft = fasttext.load_model('')
